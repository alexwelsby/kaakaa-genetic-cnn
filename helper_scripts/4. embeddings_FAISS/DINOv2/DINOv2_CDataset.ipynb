# %%
# !pip install faiss-gpu-cu12
# Out:
# Collecting faiss-gpu-cu12
#   Downloading faiss_gpu_cu12-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting numpy<2 (from faiss-gpu-cu12)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-gpu-cu12) (25.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu-cu12) (12.6.77)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu-cu12) (12.6.4.1)
# Downloading faiss_gpu_cu12-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 MB 15.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 35.4 MB/s eta 0:00:00
# Installing collected packages: numpy, faiss-gpu-cu12
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed faiss-gpu-cu12-1.12.0 numpy-1.26.4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import torch
import torchvision.transforms as T
from PIL import Image
import os
import cv2
import json
import glob
from tqdm.notebook import tqdm

# %%
# !rsync -a --info=progress2 "/content/drive/MyDrive/Datasets/DINO_DatasetC.zip" "/content"
import zipfile
with zipfile.ZipFile("DINO_DatasetC.zip", 'r') as zip_ref:
    zip_ref.extractall("./dataset/")
# Out:
#     101,143,907 100%   75.10MB/s    0:00:01 (xfr#1, to-chk=0/1)

# %%
from transformers import AutoModelForImageClassification, AutoImageProcessor

#our ViT-S DINOv2, ImageNet weights are default
dinov2_vits14 = torch.hub.load("facebookresearch/dinov2", "dinov2_vits14",pretrained=True)

device = torch.device('cuda' if torch.cuda.is_available() else "cpu")

processor = AutoImageProcessor.from_pretrained("facebook/dinov2-small", use_fast=True)
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_pretrain.pth
# 100%|██████████| 84.2M/84.2M [00:00<00:00, 270MB/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/436 [00:00<?, ?B/s]

# %%
#assumes we're passed a train, val, or test set, and that all images are within class folders
def generate_dict_from_set(path_to_dataset, start_index):
  index = start_index
  all_embeddings = []
  for folder in os.listdir(path_to_dataset):
    label = folder
    fold_path = os.path.join(path_to_dataset, folder)
    for file in os.listdir(fold_path):
      filepath = os.path.join(fold_path, file)
      all_embeddings.append({'id': index, 'label':label, 'path': filepath})
      index += 1
  return all_embeddings

dataset = generate_dict_from_set("./dataset/train", 0)
print(dataset)
# Out:
# [{'id': 0, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012307_3.jpg'}, {'id': 1, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012307_8.jpg'}, {'id': 2, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012308_0.jpg'}, {'id': 3, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012307_0.jpg'}, {'id': 4, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012309_1.jpg'}, {'id': 5, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012309_5.jpg'}, {'id': 6, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012307_5.jpg'}, {'id': 7, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012307_2.jpg'}, {'id': 8, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012309_0.jpg'}, {'id': 9, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012309_3.jpg'}, {'id': 10, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012307_6.jpg'}, {'id': 11, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012307_1.jpg'}, {'id': 12, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012307_7.jpg'}, {'id': 13, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012308_2.jpg'}, {'id': 14, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012309_4.jpg'}, {'id': 15, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012308_1.jpg'}, {'id': 16, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012335_0.jpg'}, {'id': 17, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012310_0.jpg'}, {'id': 18, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012309_2.jpg'}, {'id': 19, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012307_4.jpg'}, {'id': 20, 'label': 'K-PW', 'path': './dataset/train/K-PW/GX012306_0.jpg'}, {'id': 21, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012358_0.jpg'}, {'id': 22, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012827_15.jpg'}, {'id': 23, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013788_23.jpg'}, {'id': 24, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012364_5.jpg'}, {'id': 25, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013787_10.jpg'}, {'id': 26, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX014709_0.jpg'}, {'id': 27, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013788_28.jpg'}, {'id': 28, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013788_15.jpg'}, {'id': 29, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013422_3.jpg'}, {'id': 30, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012362_1.jpg'}, {'id': 31, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012357_20.jpg'}, {'id': 32, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012827_10.jpg'}, {'id': 33, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013028_0.jpg'}, {'id': 34, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013790_3.jpg'}, {'id': 35, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013067_7.jpg'}, {'id': 36, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013066_3.jpg'}, {'id': 37, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013403_2.jpg'}, {'id': 38, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013424_7.jpg'}, {'id': 39, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013422_6.jpg'}, {'id': 40, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012357_22.jpg'}, {'id': 41, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX014708_0.jpg'}, {'id': 42, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013423_0.jpg'}, {'id': 43, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012827_6.jpg'}, {'id': 44, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012361_14.jpg'}, {'id': 45, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013066_2.jpg'}, {'id': 46, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012363_0.jpg'}, {'id': 47, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012361_15.jpg'}, {'id': 48, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012357_17.jpg'}, {'id': 49, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013423_3.jpg'}, {'id': 50, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX012364_9.jpg'}, {'id': 51, 'label': 'KR-L', 'path': './dataset/train/KR-L/GX013788_26.jpg'}, {'id': 52, 'label': 'KR-L', 'path': './datase ...

# %%
def get_label_path_index(dataset_entry, index):
  id = dataset_entry['id']
  id = np.array([id], dtype='int64') #needs to be a 1d nparray for faiss
  label = dataset_entry['label']
  path = dataset_entry['path']
  return id, label, path

# %%
transform_image = T.Compose([T.ToTensor(),
                             T.Resize((224, 224)),
                             #T.CenterCrop(224), images are already cropped to the bird via yolo
                             T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])]) #normalizing to imagenet's means/std

def load_image(img: str) -> torch.Tensor:
    """
    Load an image and return a tensor that can be used as an input to DINOv2.
    """
    img = Image.open(img)

    transformed_img = transform_image(img)[:3].unsqueeze(0)

    return transformed_img

# %%
import faiss
from faiss import normalize_L2
def create_index(files: list, output_path) -> faiss.IndexFlatIP:
    """
    Create an index that contains all of the images in the specified list of files.
    """
    #
    dimension = 384 #we already know DINOv2 outputs this dimension
    index = faiss.IndexFlatIP(dimension) #inner product index
    index = faiss.IndexIDMap(index)


    with torch.no_grad():
      for i, entry in enumerate(tqdm(files)):
        id, label, img_path = get_label_path_index(entry, i)

        embeddings = dinov2_vits14(load_image(img_path).to(device))

        embedding = embeddings[0].cpu().numpy()

        embedding = np.array(embedding).reshape(1, -1)

        #vectors need to be normalized both before adding to the index and before searching
        normalize_L2(embedding) #for the sake of using cosine similarity

        index.add_with_ids(embedding, id)

    with open(output_path + '.paths.json', 'w') as f:
      json.dump(files, f)

    faiss.write_index(index, OUTPUT_INDEX_PATH)
    print(f"Index created and saved to {output_path}")

    return index

OUTPUT_INDEX_PATH = "/content/vector.index"
faiss_index = create_index(dataset, OUTPUT_INDEX_PATH)
# Out:
#   0%|          | 0/4044 [00:00<?, ?it/s]
# Index created and saved to /content/vector.index

# %%
# !rsync -a --info=progress2 "/content/drive/MyDrive/FAISS_index/DINOv2/Dataset_C/vector.index.paths.json" "./"
# !rsync -a --info=progress2 "/content/drive/MyDrive/FAISS_index/DINOv2/Dataset_C/vector.index" "./"
# Out:
#         185,667 100%  145.82MB/s    0:00:00 (xfr#1, to-chk=0/1)
#       3,758,186 100%   38.20MB/s    0:00:00 (xfr#1, to-chk=0/1)

# %%
# !cp vector.index.paths.json /content/drive/MyDrive/FAISS_index/DINOv2/Dataset_C/
# !cp vector.index /content/drive/MyDrive/FAISS_index/DINOv2/Dataset_C/

# %%
import faiss
import json

#https://towardsdatascience.com/building-an-image-similarity-search-engine-with-faiss-and-clip-2211126d08fa/ again
def load_faiss_index(index_path):
    index = faiss.read_index(index_path)
    with open(index_path + '.paths.json', 'r') as f:
        image_paths = json.load(f)
    print(f"Index loaded from {index_path}")
    return index, image_paths

OUTPUT_INDEX_PATH = "/content/vector.index"
faiss_index, files = load_faiss_index(OUTPUT_INDEX_PATH)
# Out:
# Index loaded from /content/vector.index

# %%
from collections import Counter
import statistics
from faiss import normalize_L2

def majority_voting_cosine(faiss_index, embeddings, files):

  correct_guesses = []
  correct_distances = []
  incorrect_distances = []
  incorrect_guesses = []
  all_distances = []

  for i, entry in enumerate(tqdm(files)):
    id, label, img_path = get_label_path_index(entry, i)

    with torch.no_grad():
      query_vectors = dinov2_vits14(load_image(img_path).to(device))

      query_vector = query_vectors[0].cpu().numpy()

      query_vector = np.array(query_vector).reshape(1, -1)

      normalize_L2(query_vector) #have to normalize to do cosine similarity


    k = 5  # Number of nearest neighbors to retrieve
    distances, indices = faiss_index.search(query_vector, k)

    all_guesses = [] #all labels of nearest neighbors
    neighbor_distances = []

    for i, index in enumerate(indices[0]):
      #print(f"index: {index}")
      #print(f"files len: {len(files)}")
      distance = distances[0][i]

      #kind of a mess. getting the associated embeddings id/label with our neighbor index
      id = embeddings[index]['id']
      new_label = embeddings[index]['label']

      all_guesses.append(new_label)
      all_distances.append(distance)
      neighbor_distances.append(distance)
      print(f"Nearest neighbor {i+1}: {id}, {new_label} Distance {distance}")

    majority_vote = Counter(all_guesses)
    winner = sorted(all_guesses, key=lambda x: majority_vote[x], reverse=True)[0]
    if winner == label:
      print(f"most common label was {winner} which == original label {label}")
      correct_guesses.append(winner)
      correct_distances.extend(neighbor_distances)
    else:
      print(f"most common label was {winner} which != {label}")
      incorrect_guesses.append(winner)
      incorrect_distances.extend(neighbor_distances)

  print(f"Total accuracy: {len(correct_guesses)/(len(correct_guesses)+len(incorrect_guesses))}")

  print(f"Median of all distances: {statistics.median(all_distances)}")

  print(f"Median distance of incorrect guesses: {statistics.median(incorrect_distances)}")

  print(f"Median distance of correct guesses: {statistics.median(correct_distances)}")

  print(f"Lowest: {min(all_distances)} highest: {max(all_distances)}")

# %%
val_dataset = generate_dict_from_set("./dataset/val", 0)
majority_voting_cosine(faiss_index, files, val_dataset)
# Out:
#   0%|          | 0/1174 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Nearest neighbor 4: 1081, -Y Distance 0.9451188445091248
# Nearest neighbor 5: 1340, -Y Distance 0.943999171257019
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1161, -Y Distance 0.9759209156036377
# Nearest neighbor 2: 978, -Y Distance 0.9702534079551697
# Nearest neighbor 3: 1453, -Y Distance 0.9695813059806824
# Nearest neighbor 4: 1017, -Y Distance 0.9675295352935791
# Nearest neighbor 5: 958, -Y Distance 0.9658051133155823
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1403, -Y Distance 0.959378182888031
# Nearest neighbor 2: 1221, -Y Distance 0.959134578704834
# Nearest neighbor 3: 1021, -Y Distance 0.957068920135498
# Nearest neighbor 4: 1010, -Y Distance 0.9562133550643921
# Nearest neighbor 5: 1404, -Y Distance 0.9540933966636658
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1430, -Y Distance 0.9732659459114075
# Nearest neighbor 2: 1119, -Y Distance 0.9686484336853027
# Nearest neighbor 3: 1265, -Y Distance 0.9681932330131531
# Nearest neighbor 4: 1441, -Y Distance 0.9678647518157959
# Nearest neighbor 5: 953, -Y Distance 0.9670848250389099
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1050, -Y Distance 0.9720429182052612
# Nearest neighbor 2: 1371, -Y Distance 0.9705188274383545
# Nearest neighbor 3: 1053, -Y Distance 0.9681557416915894
# Nearest neighbor 4: 1470, -Y Distance 0.9657485485076904
# Nearest neighbor 5: 1140, -Y Distance 0.9655212163925171
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1252, -Y Distance 0.9686350226402283
# Nearest neighbor 2: 1486, -Y Distance 0.9641836285591125
# Nearest neighbor 3: 1034, -Y Distance 0.9624406099319458
# Nearest neighbor 4: 1009, -Y Distance 0.9616039395332336
# Nearest neighbor 5: 958, -Y Distance 0.9596179723739624
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1490, -Y Distance 0.9746863842010498
# Nearest neighbor 2: 1265, -Y Distance 0.9737306833267212
# Nearest neighbor 3: 1142, -Y Distance 0.9709163904190063
# Nearest neighbor 4: 1358, -Y Distance 0.9701306223869324
# Nearest neighbor 5: 1298, -Y Distance 0.9689459800720215
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1415, -Y Distance 0.9637091159820557
# Nearest neighbor 2: 1421, -Y Distance 0.9625037908554077
# Nearest neighbor 3: 951, -Y Distance 0.9622712135314941
# Nearest neighbor 4: 1371, -Y Distance 0.9621541500091553
# Nearest neighbor 5: 1298, -Y Distance 0.9608756303787231
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1058, -Y Distance 0.9743889570236206
# Nearest neighbor 2: 1103, -Y Distance 0.9674131274223328
# Nearest neighbor 3: 1470, -Y Distance 0.9674026966094971
# Nearest neighbor 4: 1350, -Y Distance 0.9661869406700134
# Nearest neighbor 5: 1068, -Y Distance 0.965261697769165
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1089, -Y Distance 0.9439183473587036
# Nearest neighbor 2: 1255, -Y Distance 0.9337400794029236
# Nearest neighbor 3: 1354, -Y Distance 0.9334903359413147
# Nearest neighbor 4: 974, -Y Distance 0.9289034008979797
# Nearest neighbor 5: 1159, -Y Distance 0.9288098812103271
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1106, -Y Distance 0.9647916555404663
# Nearest neighbor 2: 1388, -Y Distance 0.9549868702888489
# Nearest neighbor 3: 1307, -Y Distance 0.9537440538406372
# Nearest neighbor 4: 1338, -Y Distance 0.9537150859832764
# Nearest neighbor 5: 1230, -Y Distance 0.9530341625213623
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1086, -Y Distance 0.972180962562561
# Nearest neighbor 2: 1350, -Y Distance 0.9719481468200684
# Nearest neighbor 3: 978, -Y Distance 0.9698814153671265
# Nearest neighbor 4: 1218, -Y Distance 0.9686092734336853
# Nearest neighbor 5: 1455, -Y Distance 0.9679789543151855
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1241, -Y Distance 0.9581241607666016
# Nearest neighbor 2: 1410, -Y Distance 0.9577860832214355
# Nearest neighbor 3: 1344, -Y Distance 0.957368791103363
# Nearest neighbor 4: 998, -Y Distance 0.9565510153770447
# Nearest neighbor 5: 1061, -Y Distance 0.9557149410247803
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1371, -Y Distance 0.9700510501861572
# Nearest neighbor 2: 1166, -Y Distance 0.9683326482772827
# Nearest neighbor 3: 1218, -Y Distance 0.9670355916023254
# Nearest neighbor 4: 1346, -Y Distance 0.966370701789856
# Nearest neighbor 5: 1058, -Y Distance 0.9662092924118042
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1231, -Y Distance 0.9669327735900879
# Nearest neighbor 2: 1086, -Y Distance 0.96648770570755
# Nearest neighbor 3: 1099, -Y Distance 0.9633730053901672
# Nearest neighbor 4: 1248, -Y Distance 0.9631462693214417
# Nearest neighbor 5: 1205, -Y Distance 0.9595733880996704
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1120, -Y Distance 0.9604445695877075
# Nearest neighbor 2: 1303, -Y Distance 0.9573904275894165
# Nearest neighbor 3: 1437, -Y Distance 0.9570810794830322
# Nearest neighbor 4: 1358, -Y Distance 0.9561886787414551
# Nearest neighbor 5: 1489, -Y Distance 0.9525198340415955
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1486, -Y Distance 0.9715099334716797
# Nearest neighbor 2: 1381, -Y Distance 0.9663290977478027
# Nearest neighbor 3: 1004, -Y Distance 0.9649518132209778
# Nearest neighbor 4: 1495, -Y Distance 0.9642993211746216
# Nearest neighbor 5: 1009, -Y Distance 0.9640620350837708
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1294, -Y Distance 0.9722551107406616
# Nearest neighbor 2: 1058, -Y Distance 0.9702209830284119
# Nearest neighbor 3: 1283, -Y Distance 0.9693540930747986
# Nearest neighbor 4: 978, -Y Distance 0.9692257642745972
# Nearest neighbor 5: 1148, -Y Distance 0.969021201133728
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1145, -Y Distance 0.975611686706543
# Nearest neighbor 2: 1454, -Y Distance 0.9749144911766052
# Nearest neighbor 3: 1334, -Y Distance 0.9738361239433289
# Nearest neighbor 4: 1254, -Y Distance 0.9729136228561401
# Nearest neighbor 5: 1360, -Y Distance 0.9723184704780579
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1145, -Y Distance 0.9731766581535339
# Nearest neighbor 2: 948, -Y Distance 0.9718449115753174
# Nearest neighbor 3: 1418, -Y Distance 0.9714201092720032
# Nearest neighbor 4: 1360, -Y Distance 0.9702056050300598
# Nearest neighbor 5: 1454, -Y Distance 0.9700114727020264
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1132, -Y Distance 0.9271318316459656
# Nearest neighbor 2: 1402, -Y Distance 0.9187096953392029
# Nearest neighbor 3: 1296, -Y Distance 0.9139977097511292
# Nearest neighbor 4: 1199, -Y Distance 0.8997952342033386
# Nearest neighbor 5: 1260, -Y Distance 0.8993591666221619
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1231, -Y Distance 0.9642138481140137
# Nearest neighbor 2: 1431, -Y Distance 0.95978844165802
# Nearest neighbor 3: 1323, -Y Distance 0.9583170413970947
# Nearest neighbor 4: 1016, -Y Distance 0.9580038785934448
# Nearest neighbor 5: 1218, -Y Distance 0.9575920104980469
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1409, -Y Distance 0.9654889106750488
# Nearest neighbor 2: 1432, -Y Distance 0.9653564691543579
# Nearest neighbor 3: 1041, -Y Distance 0.9636709690093994
# Nearest neighbor 4: 1404, -Y Distance 0.9614473581314087
# Nearest neighbor 5: 1302, -Y Distance 0.9613814353942871
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1140, -Y Distance 0.9594830274581909
# Nearest neighbor 2: 1410, -Y Distance 0.9588133096694946
# Nearest neighbor 3: 998, -Y Distance 0.9569587707519531
# Nearest neighbor 4: 1329, -Y Distance 0.9560827016830444
# Nearest neighbor 5: 1134, -Y Distance 0.9560469388961792
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1302, -Y Distance 0.973229169845581
# Nearest neighbor 2: 1352, -Y Distance 0.9729578495025635
# Nearest neighbor 3: 1002, -Y Distance 0.9729377031326294
# Nearest neighbor 4: 1432, -Y Distance 0.9718843698501587
# Nearest neighbor 5: 1041, -Y Distance 0.9714528322219849
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1005, -Y Distance 0.9509539008140564
# Nearest neighbor 2: 962, -Y Distance 0.9500042200088501
# Nearest neighbor 3: 1044, -Y Distance 0.9487261772155762
# Nearest neighbor 4: 1483, -Y Distance 0.9464131593704224
# Nearest neighbor 5: 1416, -Y Distance 0.9447181224822998
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1352, -Y Distance 0.9743639826774597
# Nearest neighbor 2: 1024, -Y Distance 0.9734318852424622
# Nearest neighbor 3: 1302, -Y Distance 0.9722789525985718
# Nearest neighbor 4: 1041, -Y Distance 0.9711959362030029
# Nearest neighbor 5: 1385, -Y Distance 0.9695879220962524
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1185, -Y Distance 0.9787425994873047
# Nearest neighbor 2: 1155, -Y Distance 0.9714575409889221
# Nearest neighbor 3: 1254, -Y Distance 0.9707019329071045
# Nearest neighbor 4: 1491, -Y Distance 0.969383716583252
# Nearest neighbor 5: 1360, -Y Distance 0.9686084389686584
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1404, -Y Distance 0.972882091999054
# Nearest neighbor 2: 1055, -Y Distance 0.9691311717033386
# Nearest neighbor 3: 1246, -Y Distance 0.9682813286781311
# Nearest neighbor 4: 1352, -Y Distance 0.9678847193717957
# Nearest neighbor 5: 1006, -Y Distance 0.9678620100021362
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1014, -Y Distance 0.9702109098434448
# Nearest neighbor 2: 1106, -Y Distance 0.968241274356842
# Nearest neighbor 3: 1388, -Y Distance 0.9678599834442139
# Nearest neighbor 4: 1212, -Y Distance 0.966589093208313
# Nearest neighbor 5: 949, -Y Distance 0.966356635093689
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1022, -Y Distance 0.9511266946792603
# Nearest neighbor 2: 1311, -Y Distance 0.9476292133331299
# Nearest neighbor 3: 1309, -Y Distance 0.9465523362159729
# Nearest neighbor 4: 1342, -Y Distance 0.9456323981285095
# Nearest neighbor 5: 1321, -Y Distance 0.9436907172203064
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1142, -Y Distance 0.9715625643730164
# Nearest neighbor 2: 986, -Y Distance 0.9686092734336853
# Nearest neighbor 3: 1050, -Y Distance 0.9665127396583557
# Nearest neighbor 4: 1240, -Y Distance 0.965929388999939
# Nearest neighbor 5: 1012, -Y Distance 0.9653559923171997
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1283, -Y Distance 0.972917914390564
# Nearest neighbor 2: 1086, -Y Distance 0.9719130992889404
# Nearest neighbor 3: 1166, -Y Distance 0.9717548489570618
# Nearest neighbor 4: 1371, -Y Distance 0.9711363911628723
# Nearest neighbor 5: 1356, -Y Distance 0.9708102941513062
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1427, -Y Distance 0.9771485328674316
# Nearest neighbor 2: 968, -Y Distance 0.9715128540992737
# Nearest neighbor 3: 994, -Y Distance 0.9714154005050659
# Nearest neighbor 4: 1222, -Y Distance 0.9713060259819031
# Nearest neighbor 5: 1454, -Y Distance 0.9712204933166504
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1432, -Y Distance 0.9723677635192871
# Nearest neighbor 2: 958, -Y Distance 0.9695612192153931
# Nearest neighbor 3: 1481, -Y Distance 0.9687017798423767
# Nearest neighbor 4: 1404, -Y Distance 0.9656338095664978
# Nearest neighbor 5: 1024, -Y Distance 0.96524977684021
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 976, -Y Distance 0.9594087600708008
# Nearest neighbor 2: 1363, -Y Distance 0.9559602737426758
# Nearest neighbor 3: 1502, -Y Distance 0.9552456140518188
# Nearest neighbor 4: 1268, -Y Distance 0.9551430940628052
# Nearest neighbor 5: 1364, -Y Distance 0.9518908858299255
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 968, -Y Distance 0.9671000242233276
# Nearest neighbor 2: 1213, -Y Distance 0.9667837619781494
# Nearest neighbor 3: 1376, -Y Distance 0.9658367037773132
# Nearest neighbor 4: 1185, -Y Distance 0.9657952785491943
# Nearest neighbor 5: 1398, -Y Distance 0.9638723134994507
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1161, -Y Distance 0.9748833775520325
# Nearest neighbor 2: 1453, -Y Distance 0.9728267192840576
# Nearest neighbor 3: 978, -Y Distance 0.9726080894470215
# Nearest neighbor 4: 1304, -Y Distance 0.9699666500091553
# Nearest neighbor 5: 1086, -Y Distance 0.969405472278595
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1177, -Y Distance 0.976545512676239
# Nearest neighbor 2: 1306, -Y Distance 0.9759246110916138
# Nearest neighbor 3: 1142, -Y Distance 0.9704115986824036
# Nearest neighbor 4: 1028, -Y Distance 0.9702514410018921
# Nearest neighbor 5: 1113, -Y Distance 0.9684129953384399
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1007, -Y Distance 0.9609935879707336
# Nearest neighbor 2: 1266, -Y Distance 0.9595815539360046
# Nearest neighbor 3: 1495, -Y Distance 0.9561963081359863
# Nearest neighbor 4: 1482, -Y Distance 0.9560312628746033
# Nearest neighbor 5: 1451, -Y Distance 0.954538881778717
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1477, -Y Distance 0.9748690724372864
# Nearest neighbor 2: 1002, -Y Distance 0.9696942567825317
# Nearest neighbor 3: 1404, -Y Distance 0.9696746468544006
# Nearest neighbor 4: 1153, -Y Distance 0.9684007167816162
# Nearest neighbor 5: 958, -Y Distance 0.9677857160568237
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1231, -Y Distance 0.9670559763908386
# Nearest neighbor 2: 1130, -Y Distance 0.9666923880577087
# Nearest neighbor 3: 1412, -Y Distance 0.9658968448638916
# Nearest neighbor 4: 1092, -Y Distance 0.9635001420974731
# Nearest neighbor 5: 1125, -Y Distance 0.9632446765899658
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1352, -Y Distance 0.9695678949356079
# Nearest neighbor 2: 1432, -Y Distance 0.9676892161369324
# Nearest neighbor 3: 1385, -Y Distance 0.964465856552124
# Nearest neighbor 4: 1404, -Y Distance 0.9634320735931396
# Nearest neighbor 5: 1024, -Y Distance 0.9621564745903015
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 978, -Y Distance 0.9757551550865173
# Nearest neighbor 2: 1209, -Y Distance 0.970974326133728
# Nearest neighbor 3: 1161, -Y Distance 0.9704281687736511
# Nearest neighbor 4: 1265, -Y Distance 0.9698056578636169
# Nearest neighbor 5: 1453, -Y Distance 0.9696359634399414
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1433, -Y Distance 0.9724035263061523
# Nearest neighbor 2: 1286, -Y Distance 0.9679543972015381
# Nearest neighbor 3: 1283, -Y Distance 0.967720091342926
# Nearest neighbor 4: 1160, -Y Distance 0.9663925170898438
# Nearest neighbor 5: 1142, -Y Distance 0.9660745859146118
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1211, -Y Distance 0.966174304485321
# Nearest neighbor 2: 1063, -Y Distance 0.9649868607521057
# Nearest neighbor 3: 1313, -Y Distance 0.9643760323524475
# Nearest neighbor 4: 1003, -Y Distance 0.960913896560669
# Nearest neighbor 5: 1366, -Y Distance 0.9608384370803833
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1359, -Y Distance 0.9706495404243469
# Nearest neighbor 2: 1211, -Y Distance 0.967034101486206
# Nearest neighbor 3: 1003, -Y Distance 0.9643124938011169
# Nearest neighbor 4: 1248, -Y Distance 0.9643024802207947
# Nearest neighbor 5: 1063, -Y Distance 0.9632498621940613
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1013, -Y Distance 0.9339032769203186
# Nearest neighbor 2: 1089, -Y Distance 0.9335494637489319
# Nearest neighbor 3: 1354, -Y Distance 0.9330704808235168
# Nearest neighbor 4: 997, -Y Distance 0.9302314519882202
# Nearest neighbor 5: 3417, B- Distance 0.9272361397743225
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1241, -Y Distance 0.9672868847846985
# Nearest neighbor 2: 1301, -Y Distance 0.9649186730384827
# Nearest neighbor 3: 1283, -Y Distance 0.9646434783935547
# Nearest neighbor 4: 1190, -Y Distance 0.9610930681228638
# Nearest neighbor 5: 1172, -Y Distance 0.9592875242233276
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1041, -Y Distance 0.9648407101631165
# Nearest neighbor 2: 1432, -Y Distance 0.9642466306686401
# Nearest neighbor 3: 1302, -Y Distance 0.963471531867981
# Nearest neighbor 4: 1352, -Y Distance 0.9634542465209961
# Nearest neighbor 5: 995, -Y Distance 0.9609634876251221
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1322, -Y Distance 0.9749767780303955
# Nearest neighbor 2: 1040, -Y Distance 0.9690099358558655
# Nearest neighbor 3: 1105, -Y Distance 0.968948483467102
# Nearest neighbor 4: 1098, -Y Distance 0.9677813053131104
# Nearest neighbor 5: 1232, -Y Distance 0.9676418304443359
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1210, -Y Distance 0.975223958492279
# Nearest neighbor 2: 1284, -Y Distance 0.9679532051086426
# Nearest neighbor 3: 948, -Y Distance 0.9679471254348755
# Nearest neighbor 4: 1080, -Y Distance 0.9670698642730713
# Nearest neighbor 5: 1254, -Y Distance 0.9647953510284424
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1350, -Y Distance 0.9734799861907959
# Nearest neighbor 2: 1311, -Y Distance 0.9663989543914795
# Nearest neighbor 3: 1152, -Y Distance 0.9659606218338013
# Nearest neighbor 4: 1036, -Y Distance 0.9654030799865723
# Nearest neighbor 5: 1329, -Y Distance 0.9641819000244141
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1058, -Y Distance 0.9734148979187012
# Nearest neighbor 2: 1154, -Y Distance 0.972513735294342
# Nearest neighbor 3: 1068, -Y Distance 0.9696568846702576
# Nearest neighbor 4: 1294, -Y Distance 0.9694031476974487
# Nearest neighbor 5: 1103, -Y Distance 0.9691476821899414
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1337, -Y Distance 0.933051586151123
# Nearest neighbor 2: 1144, -Y Distance 0.9314768314361572
# Nearest neighbor 3: 1364, -Y Distance 0.9291208982467651
# Nearest neighbor 4: 1296, -Y Distance 0.9282715916633606
# Nearest neighbor 5: 1463, -Y Distance 0.927013635635376
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1353, -Y Distance 0.9703455567359924
# Nearest neighbor 2: 1498, -Y Distance 0.9696966409683228
# Nearest neighbor 3: 1368, -Y Distance 0.9689534306526184
# Nearest neighbor 4: 1272, -Y Distance 0.9670513868331909
# Nearest neighbor 5: 1037, -Y Distance 0.9669003486633301
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 975, -Y Distance 0.9730085134506226
# Nearest neighbor 2: 1358, -Y Distance 0.9721463918685913
# Nearest neighbor 3: 1069, -Y Distance 0.9717800617218018
# Nearest neighbor 4: 1421, -Y Distance 0.9710167050361633
# Nearest neighbor 5: 1348, -Y Distance 0.9707103371620178
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1085, -Y Distance 0.9651151299476624
# Nearest neighbor 2: 1311, -Y Distance 0.9648720622062683
# Nearest neighbor 3: 1265, -Y Distance 0.9633510708808899
# Nearest neighbor 4: 1441, -Y Distance 0.9617409110069275
# Nearest neighbor 5: 1200, -Y Distance 0.9614494442939758
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1113, -Y Distance 0.9622255563735962
# Nearest neighbor 2: 1273, -Y Distance 0.9598727226257324
# Nearest neighbor 3: 1416, -Y Distance 0.9566578269004822
# Nearest neighbor 4: 1357, -Y Distance 0.9561573266983032
# Nearest neighbor 5: 1306, -Y Distance 0.955330491065979
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1291, -Y Distance 0.969715416431427
# Nearest neighbor 2: 1359, -Y Distance 0.960776686668396
# Nearest neighbor 3: 1247, -Y Distance 0.9606738090515137
# Nearest neighbor 4: 1047, -Y Distance 0.9573884010314941
# Nearest neighbor 5: 1431, -Y Distance 0.9560081958770752
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 994, -Y Distance 0.9716968536376953
# Nearest neighbor 2: 1210, -Y Distance 0.9707320332527161
# Nearest neighbor 3: 1295, -Y Distance 0.9704573154449463
# Nearest neighbor 4: 1171, -Y Distance 0.9701486229896545
# Nearest neighbor 5: 1254, -Y Distance 0.9694511294364929
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1437, -Y Distance 0.9782747626304626
# Nearest neighbor 2: 1335, -Y Distance 0.9710142612457275
# Nearest neighbor 3: 949, -Y Distance 0.9647312164306641
# Nearest neighbor 4: 1290, -Y Distance 0.9638129472732544
# Nearest neighbor 5: 1016, -Y Distance 0.9621309041976929
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1154, -Y Distance 0.9724733233451843
# Nearest neighbor 2: 1316, -Y Distance 0.9723912477493286
# Nearest neighbor 3: 1103, -Y Distance 0.9699808955192566
# Nearest neighbor 4: 1148, -Y Distance 0.9682160019874573
# Nearest neighbor 5: 1470, -Y Distance 0.9677505493164062
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1177, -Y Distance 0.9685931205749512
# Nearest neighbor 2: 1352, -Y Distance 0.968051016330719
# Nearest neighbor 3: 1028, -Y Distance 0.9647055864334106
# Nearest neighbor 4: 1404, -Y Distance 0.9646770358085632
# Nearest neighbor 5: 1357, -Y Distance 0.9638229012489319
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1437, -Y Distance 0.9687670469284058
# Nearest neighbor 2: 1342, -Y Distance 0.9661263823509216
# Nearest neighbor 3: 1212, -Y Distance 0.9605425596237183
# Nearest neighbor 4: 1040, -Y Distance 0.9582884907722473
# Nearest neighbor 5: 1016, -Y Distance 0.9576132893562317
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 963, -Y Distance 0.9478163719177246
# Nearest neighbor 2: 1342, -Y Distance 0.9474722146987915
# Nearest neighbor 3: 1311, -Y Distance 0.9473991394042969
# Nearest neighbor 4: 1439, -Y Distance 0.9441869854927063
# Nearest neighbor 5: 1022, -Y Distance 0.9405354261398315
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 968, -Y Distance 0.9691437482833862
# Nearest neighbor 2: 1376, -Y Distance 0.9660133123397827
# Nearest neighbor 3: 1427, -Y Distance 0.9615107774734497
# Nearest neighbor 4: 1222, -Y Distance 0.9578012228012085
# Nearest neighbor 5: 1442, -Y Distance 0.9576407074928284
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1447, -Y Distance 0.9697403907775879
# Nearest neighbor 2: 1095, -Y Distance 0.9685800075531006
# Nearest neighbor 3: 1262, -Y Distance 0.9674959182739258
# Nearest neighbor 4: 1322, -Y Distance 0.966448187828064
# Nearest neighbor 5: 1092, -Y Distance 0.9663269519805908
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1079, -Y Distance 0.9638424515724182
# Nearest neighbor 2: 1016, -Y Distance 0.9623308777809143
# Nearest neighbor 3: 1309, -Y Distance 0.9621680378913879
# Nearest neighbor 4: 1412, -Y Distance 0.9612128138542175
# Nearest neighbor 5: 1290, -Y Distance 0.959288477897644
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1012, -Y Distance 0.9628515243530273
# Nearest neighbor 2: 1298, -Y Distance 0.9627105593681335
# Nearest neighbor 3: 1316, -Y Distance 0.9596973657608032
# Nearest neighbor 4: 1142, -Y Distance 0.9593501091003418
# Nearest neighbor 5: 1305, -Y Distance 0.9589046239852905
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1218, -Y Distance 0.9698154926300049
# Nearest neighbor 2: 1350, -Y Distance 0.9676194190979004
# Nearest neighbor 3: 1193, -Y Distance 0.9675863981246948
# Nearest neighbor 4: 1371, -Y Distance 0.9673518538475037
# Nearest neighbor 5: 1103, -Y Distance 0.9655628204345703
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1470, -Y Distance 0.973020613193512
# Nearest neighbor 2: 1050, -Y Distance 0.9693981409072876
# Nearest neighbor 3: 1265, -Y Distance 0.9689038395881653
# Nearest neighbor 4: 990, -Y Distance 0.9685302376747131
# Nearest neighbor 5: 953, -Y Distance 0.9683079123497009
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1316, -Y Distance 0.9736601114273071
# Nearest neighbor 2: 1420, -Y Distance 0.9736392498016357
# Nearest neighbor 3: 1148, -Y Distance 0.9728043079376221
# Nearest neighbor 4: 1237, -Y Distance 0.9723727703094482
# Nearest neighbor 5: 1391, -Y Distance 0.9722532033920288
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1283, -Y Distance 0.9703642129898071
# Nearest neighbor 2: 1358, -Y Distance 0.9653589725494385
# Nearest neighbor 3: 986, -Y Distance 0.9648735523223877
# Nearest neighbor 4: 1413, -Y Distance 0.964547872543335
# Nearest neighbor 5: 1286, -Y Distance 0.9642609357833862
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1086, -Y Distance 0.9700172543525696
# Nearest neighbor 2: 1218, -Y Distance 0.9680633544921875
# Nearest neighbor 3: 1356, -Y Distance 0.9678243398666382
# Nearest neighbor 4: 1350, -Y Distance 0.9663171768188477
# Nearest neighbor 5: 1166, -Y Distance 0.9662348628044128
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 986, -Y Distance 0.9747521281242371
# Nearest neighbor 2: 1142, -Y Distance 0.9714452624320984
# Nearest neighbor 3: 1032, -Y Distance 0.9710589647293091
# Nearest neighbor 4: 1348, -Y Distance 0.967556893825531
# Nearest neighbor 5: 1433, -Y Distance 0.966400146484375
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1081, -Y Distance 0.9606224894523621
# Nearest neighbor 2: 1421, -Y Distance 0.958919107913971
# Nearest neighbor 3: 1303, -Y Distance 0.9565937519073486
# Nearest neighbor 4: 1358, -Y Distance 0.9559233784675598
# Nearest neighbor 5: 1413, -Y Distance 0.9538965225219727
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1436, -Y Distance 0.9508639574050903
# Nearest neighbor 2: 1319, -Y Distance 0.9500480890274048
# Nearest neighbor 3: 1259, -Y Distance 0.9495336413383484
# Nearest neighbor 4: 1146, -Y Distance 0.9419975280761719
# Nearest neighbor 5: 1487, -Y Distance 0.9399771690368652
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1455, -Y Distance 0.9716425538063049
# Nearest neighbor 2: 1142, -Y Distance 0.9705640077590942
# Nearest neighbor 3: 1490, -Y Distance 0.9701992273330688
# Nearest neighbor 4: 1058, -Y Distance 0.9699130058288574
# Nearest neighbor 5: 1415, -Y Distance 0.9694260358810425
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1486, -Y Distance 0.9719386696815491
# Nearest neighbor 2: 1125, -Y Distance 0.9710218906402588
# Nearest neighbor 3: 1040, -Y Distance 0.9703826308250427
# Nearest neighbor 4: 1100, -Y Distance 0.9698479175567627
# Nearest neighbor 5: 1092, -Y Distance 0.9692522883415222
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1365, -Y Distance 0.9625604152679443
# Nearest neighbor 2: 1050, -Y Distance 0.9580416679382324
# Nearest neighbor 3: 1311, -Y Distance 0.9538151025772095
# Nearest neighbor 4: 1342, -Y Distance 0.9515664577484131
# Nearest neighbor 5: 1439, -Y Distance 0.9513550996780396
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1265, -Y Distance 0.9732269644737244
# Nearest neighbor 2: 992, -Y Distance 0.9710347056388855
# Nearest neighbor 3: 1161, -Y Distance 0.9679077863693237
# Nearest neighbor 4: 1209, -Y Distance 0.9667227268218994
# Nearest neighbor 5: 1240, -Y Distance 0.9664061665534973
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 975, -Y Distance 0.9527299404144287
# Nearest neighbor 2: 1283, -Y Distance 0.9504719972610474
# Nearest neighbor 3: 1413, -Y Distance 0.9494993686676025
# Nearest neighbor 4: 1358, -Y Distance 0.9494118690490723
# Nearest neighbor 5: 1235, -Y Distance 0.9463745951652527
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1385, -Y Distance 0.9760308265686035
# Nearest neighbor 2: 1357, -Y Distance 0.9727501273155212
# Nearest neighbor 3: 1352, -Y Distance 0.9719105958938599
# Nearest neighbor 4: 1055, -Y Distance 0.9706871509552002
# Nearest neighbor 5: 1002, -Y Distance 0.9700288772583008
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1413, -Y Distance 0.9645664095878601
# Nearest neighbor 2: 1160, -Y Distance 0.9567775726318359
# Nearest neighbor 3: 1487, -Y Distance 0.9558795094490051
# Nearest neighbor 4: 1433, -Y Distance 0.9540826082229614
# Nearest neighbor 5: 1273, -Y Distance 0.9530775547027588
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1017, -Y Distance 0.9627976417541504
# Nearest neighbor 2: 1037, -Y Distance 0.9589983820915222
# Nearest neighbor 3: 1001, -Y Distance 0.9575439691543579
# Nearest neighbor 4: 1482, -Y Distance 0.9570621252059937
# Nearest neighbor 5: 1231, -Y Distance 0.9569780826568604
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1230, -Y Distance 0.9648256897926331
# Nearest neighbor 2: 1349, -Y Distance 0.9645262956619263
# Nearest neighbor 3: 1069, -Y Distance 0.9645015001296997
# Nearest neighbor 4: 1388, -Y Distance 0.9644525051116943
# Nearest neighbor 5: 1308, -Y Distance 0.9634513258934021
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1036, -Y Distance 0.9714544415473938
# Nearest neighbor 2: 1197, -Y Distance 0.9714011549949646
# Nearest neighbor 3: 1307, -Y Distance 0.9704414010047913
# Nearest neighbor 4: 1154, -Y Distance 0.9695625305175781
# Nearest neighbor 5: 1371, -Y Distance 0.9670604467391968
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1329, -Y Distance 0.9681447744369507
# Nearest neighbor 2: 1410, -Y Distance 0.9658595323562622
# Nearest neighbor 3: 998, -Y Distance 0.9635770916938782
# Nearest neighbor 4: 1014, -Y Distance 0.9619038105010986
# Nearest neighbor 5: 1036, -Y Distance 0.9607638120651245
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1437, -Y Distance 0.9630489349365234
# Nearest neighbor 2: 1218, -Y Distance 0.9613437652587891
# Nearest neighbor 3: 1079, -Y Distance 0.9571151733398438
# Nearest neighbor 4: 949, -Y Distance 0.9570993185043335
# Nearest neighbor 5: 1358, -Y Distance 0.9566036462783813
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1265, -Y Distance 0.9688392281532288
# Nearest neighbor 2: 1470, -Y Distance 0.9687707424163818
# Nearest neighbor 3: 1085, -Y Distance 0.9686453938484192
# Nearest neighbor 4: 978, -Y Distance 0.967047393321991
# Nearest neighbor 5: 1441, -Y Distance 0.9666231274604797
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1062, -Y Distance 0.9457764625549316
# Nearest neighbor 2: 1358, -Y Distance 0.9456729292869568
# Nearest neighbor 3: 1365, -Y Distance 0.944922924041748
# Nearest neighbor 4: 1249, -Y Distance 0.9415791034698486
# Nearest neighbor 5: 1413, -Y Distance 0.9375652074813843
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1040, -Y Distance 0.9644057750701904
# Nearest neighbor 2: 985, -Y Distance 0.96159827709198
# Nearest neighbor 3: 1218, -Y Distance 0.9613600969314575
# Nearest neighbor 4: 1412, -Y Distance 0.9610790014266968
# Nearest neighbor 5: 1325, -Y Distance 0.9608542919158936
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1002, -Y Distance 0.977343738079071
# Nearest neighbor 2: 958, -Y Distance 0.9709668159484863
# Nearest neighbor 3: 1306, -Y Distance 0.9694384336471558
# Nearest neighbor 4: 1477, -Y Distance 0.9693446159362793
# Nearest neighbor 5: 1204, -Y Distance 0.9691628813743591
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1246, -Y Distance 0.9774210453033447
# Nearest neighbor 2: 1302, -Y Distance 0.9758799076080322
# Nearest neighbor 3: 1352, -Y Distance 0.9742071032524109
# Nearest neighbor 4: 1357, -Y Distance 0.9735827445983887
# Nearest neighbor 5: 1385, -Y Distance 0.9728036522865295
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1216, -Y Distance 0.9575355052947998
# Nearest neighbor 2: 1199, -Y Distance 0.9527369141578674
# Nearest neighbor 3: 1160, -Y Distance 0.9498752355575562
# Nearest neighbor 4: 1327, -Y Distance 0.9475482702255249
# Nearest neighbor 5: 1421, -Y Distance 0.9475264549255371
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1215, -Y Distance 0.9781773686408997
# Nearest neighbor 2: 1454, -Y Distance 0.976375937461853
# Nearest neighbor 3: 1284, -Y Distance 0.9763385057449341
# Nearest neighbor 4: 970, -Y Distance 0.9758251905441284
# Nearest neighbor 5: 1418, -Y Distance 0.9751951694488525
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1159, -Y Distance 0.9250860810279846
# Nearest neighbor 2: 1340, -Y Distance 0.924735426902771
# Nearest neighbor 3: 1201, -Y Distance 0.9234969615936279
# Nearest neighbor 4: 1494, -Y Distance 0.9181527495384216
# Nearest neighbor 5: 1364, -Y Distance 0.9142730236053467
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1432, -Y Distance 0.977374792098999
# Nearest neighbor 2: 1302, -Y Distance 0.9712337851524353
# Nearest neighbor 3: 1116, -Y Distance 0.9685502052307129
# Nearest neighbor 4: 1352, -Y Distance 0.9678879976272583
# Nearest neighbor 5: 1385, -Y Distance 0.9673725366592407
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1199, -Y Distance 0.9371004104614258
# Nearest neighbor 2: 997, -Y Distance 0.9325745105743408
# Nearest neighbor 3: 1112, -Y Distance 0.9314900040626526
# Nearest neighbor 4: 1354, -Y Distance 0.9291888475418091
# Nearest neighbor 5: 1043, -Y Distance 0.9261773824691772
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1311, -Y Distance 0.9622631072998047
# Nearest neighbor 2: 1448, -Y Distance 0.9615187048912048
# Nearest neighbor 3: 1439, -Y Distance 0.959871232509613
# Nearest neighbor 4: 1365, -Y Distance 0.9590000510215759
# Nearest neighbor 5: 1022, -Y Distance 0.957778811454773
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1432, -Y Distance 0.9669474959373474
# Nearest neighbor 2: 1076, -Y Distance 0.9665623903274536
# Nearest neighbor 3: 1031, -Y Distance 0.9634220004081726
# Nearest neighbor 4: 1357, -Y Distance 0.963346540927887
# Nearest neighbor 5: 1352, -Y Distance 0.9594181776046753
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1150, -Y Distance 0.9755178093910217
# Nearest neighbor 2: 1142, -Y Distance 0.9718422293663025
# Nearest neighbor 3: 1357, -Y Distance 0.9693816900253296
# Nearest neighbor 4: 1352, -Y Distance 0.9691675305366516
# Nearest neighbor 5: 1385, -Y Distance 0.9685289263725281
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1388, -Y Distance 0.9725355505943298
# Nearest neighbor 2: 1437, -Y Distance 0.9713568091392517
# Nearest neighbor 3: 1166, -Y Distance 0.9698885679244995
# Nearest neighbor 4: 1230, -Y Distance 0.9689280390739441
# Nearest neighbor 5: 1350, -Y Distance 0.9666808247566223
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 981, -Y Distance 0.9658970832824707
# Nearest neighbor 2: 1154, -Y Distance 0.9640690088272095
# Nearest neighbor 3: 1306, -Y Distance 0.9625991582870483
# Nearest neighbor 4: 1126, -Y Distance 0.9609540700912476
# Nearest neighbor 5: 1480, -Y Distance 0.9589786529541016
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 986, -Y Distance 0.9597538709640503
# Nearest neighbor 2: 1403, -Y Distance 0.9570096731185913
# Nearest neighbor 3: 954, -Y Distance 0.9563277959823608
# Nearest neighbor 4: 1216, -Y Distance 0.9559810757637024
# Nearest neighbor 5: 981, -Y Distance 0.9538114070892334
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1444, -Y Distance 0.9620013236999512
# Nearest neighbor 2: 1359, -Y Distance 0.9590430855751038
# Nearest neighbor 3: 1231, -Y Distance 0.9577925801277161
# Nearest neighbor 4: 1047, -Y Distance 0.957222580909729
# Nearest neighbor 5: 1431, -Y Distance 0.9567447304725647
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1451, -Y Distance 0.9713804125785828
# Nearest neighbor 2: 1368, -Y Distance 0.9692083597183228
# Nearest neighbor 3: 1353, -Y Distance 0.9684436321258545
# Nearest neighbor 4: 1007, -Y Distance 0.9634992480278015
# Nearest neighbor 5: 1498, -Y Distance 0.9629469513893127
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1137, -Y Distance 0.9193896055221558
# Nearest neighbor 2: 965, -Y Distance 0.9028257131576538
# Nearest neighbor 3: 1340, -Y Distance 0.8972957730293274
# Nearest neighbor 4: 1163, -Y Distance 0.8871662020683289
# Nearest neighbor 5: 1270, -Y Distance 0.8820681571960449
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1322, -Y Distance 0.9707512259483337
# Nearest neighbor 2: 1447, -Y Distance 0.9706887006759644
# Nearest neighbor 3: 1092, -Y Distance 0.969951868057251
# Nearest neighbor 4: 1427, -Y Distance 0.9697715044021606
# Nearest neighbor 5: 1326, -Y Distance 0.9691154956817627
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1374, -Y Distance 0.9700058102607727
# Nearest neighbor 2: 1003, -Y Distance 0.9623664021492004
# Nearest neighbor 3: 1211, -Y Distance 0.9608484506607056
# Nearest neighbor 4: 1366, -Y Distance 0.9608353972434998
# Nearest neighbor 5: 1297, -Y Distance 0.9605303406715393
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1322, -Y Distance 0.9735677242279053
# Nearest neighbor 2: 1098, -Y Distance 0.9726186394691467
# Nearest neighbor 3: 1486, -Y Distance 0.9717643857002258
# Nearest neighbor 4: 1004, -Y Distance 0.9709410667419434
# Nearest neighbor 5: 1326, -Y Distance 0.9691674113273621
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1364, -Y Distance 0.9648473858833313
# Nearest neighbor 2: 1440, -Y Distance 0.9641481041908264
# Nearest neighbor 3: 1190, -Y Distance 0.9515275955200195
# Nearest neighbor 4: 1111, -Y Distance 0.951107382774353
# Nearest neighbor 5: 1163, -Y Distance 0.9496378898620605
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1388, -Y Distance 0.9678930044174194
# Nearest neighbor 2: 1262, -Y Distance 0.9671663045883179
# Nearest neighbor 3: 1100, -Y Distance 0.9670717716217041
# Nearest neighbor 4: 1322, -Y Distance 0.9658671617507935
# Nearest neighbor 5: 998, -Y Distance 0.9657766222953796
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1235, -Y Distance 0.9628785848617554
# Nearest neighbor 2: 1409, -Y Distance 0.9563340544700623
# Nearest neighbor 3: 1302, -Y Distance 0.9554821848869324
# Nearest neighbor 4: 1417, -Y Distance 0.9521324634552002
# Nearest neighbor 5: 1115, -Y Distance 0.9520695805549622
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1440, -Y Distance 0.9590955972671509
# Nearest neighbor 2: 1364, -Y Distance 0.9553848505020142
# Nearest neighbor 3: 976, -Y Distance 0.9498359560966492
# Nearest neighbor 4: 982, -Y Distance 0.949459433555603
# Nearest neighbor 5: 1281, -Y Distance 0.9477853178977966
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 954, -Y Distance 0.9663658738136292
# Nearest neighbor 2: 1200, -Y Distance 0.9660089015960693
# Nearest neighbor 3: 1265, -Y Distance 0.9657817482948303
# Nearest neighbor 4: 1237, -Y Distance 0.9650936722755432
# Nearest neighbor 5: 986, -Y Distance 0.9647815823554993
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1431, -Y Distance 0.9608592987060547
# Nearest neighbor 2: 1130, -Y Distance 0.9559419751167297
# Nearest neighbor 3: 1016, -Y Distance 0.9492278099060059
# Nearest neighbor 4: 1099, -Y Distance 0.9484566450119019
# Nearest neighbor 5: 1183, -Y Distance 0.9475179314613342
# most common label was -Y which == original label -Y
# Nearest neighbor 1: 1669, WX-P Distance 0.8943569660186768
# Nearest neighbor 2: 494, O-LW Distance 0.8718295097351074
# Nearest neighbor 3: 3055, B- Distance 0.8675997257232666
# Nearest neighbor 4: 2768, B- Distance 0.8646533489227295
# Nearest neighbor 5: 2843, B- Distance 0.8617054224014282
# most common label was B- which != WX-P
# Nearest neighbor 1: 1665, WX-P Distance 0.9551209211349487
# Nearest neighbor 2: 1545, WX-P Distance 0.9527217745780945
# Nearest neighbor 3: 1540, WX-P Distance 0.948459267616272
# Nearest neighbor 4: 1658, WX-P Distance 0.9437664747238159
# Nearest neighbor 5: 1773, WX-P Distance 0.9397405385971069
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1754, WX-P Distance 0.9462854862213135
# Nearest neighbor 2: 1626, WX-P Distance 0.9423699378967285
# Nearest neighbor 3: 1568, WX-P Distance 0.9384247064590454
# Nearest neighbor 4: 1844, WX-P Distance 0.9380501508712769
# Nearest neighbor 5: 1750, WX-P Distance 0.9370214939117432
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1605, WX-P Distance 0.9327271580696106
# Nearest neighbor 2: 1618, WX-P Distance 0.9291789531707764
# Nearest neighbor 3: 1526, WX-P Distance 0.9281917214393616
# Nearest neighbor 4: 1586, WX-P Distance 0.9266955256462097
# Nearest neighbor 5: 1621, WX-P Distance 0.9243475198745728
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1632, WX-P Distance 0.9504297971725464
# Nearest neighbor 2: 1759, WX-P Distance 0.9482764005661011
# Nearest neighbor 3: 1719, WX-P Distance 0.9427922368049622
# Nearest neighbor 4: 1639, WX-P Distance 0.9410812854766846
# Nearest neighbor 5: 1653, WX-P Distance 0.9407509565353394
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1723, WX-P Distance 0.9130555391311646
# Nearest neighbor 2: 1696, WX-P Distance 0.9111101627349854
# Nearest neighbor 3: 1798, WX-P Distance 0.9095050692558289
# Nearest neighbor 4: 1813, WX-P Distance 0.9089291095733643
# Nearest neighbor 5: 1768, WX-P Distance 0.9083658456802368
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1593, WX-P Distance 0.9641971588134766
# Nearest neighbor 2: 1805, WX-P Distance 0.949059784412384
# Nearest neighbor 3: 1722, WX-P Distance 0.9467805624008179
# Nearest neighbor 4: 1540, WX-P Distance 0.9458478689193726
# Nearest neighbor 5: 1661, WX-P Distance 0.9451814889907837
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1693, WX-P Distance 0.9418920278549194
# Nearest neighbor 2: 1657, WX-P Distance 0.9402979612350464
# Nearest neighbor 3: 1838, WX-P Distance 0.9371000528335571
# Nearest neighbor 4: 1805, WX-P Distance 0.936532735824585
# Nearest neighbor 5: 1581, WX-P Distance 0.9360711574554443
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1816, WX-P Distance 0.9640877842903137
# Nearest neighbor 2: 1764, WX-P Distance 0.9531249403953552
# Nearest neighbor 3: 1559, WX-P Distance 0.9526291489601135
# Nearest neighbor 4: 1760, WX-P Distance 0.9522690773010254
# Nearest neighbor 5: 1715, WX-P Distance 0.9515151977539062
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1838, WX-P Distance 0.9553351998329163
# Nearest neighbor 2: 1811, WX-P Distance 0.9474657773971558
# Nearest neighbor 3: 1540, WX-P Distance 0.9423477649688721
# Nearest neighbor 4: 1784, WX-P Distance 0.9387457370758057
# Nearest neighbor 5: 1657, WX-P Distance 0.9378374814987183
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1662, WX-P Distance 0.9585257768630981
# Nearest neighbor 2: 1675, WX-P Distance 0.955746054649353
# Nearest neighbor 3: 1654, WX-P Distance 0.9513314962387085
# Nearest neighbor 4: 1780, WX-P Distance 0.9506069421768188
# Nearest neighbor 5: 1535, WX-P Distance 0.9489469528198242
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1559, WX-P Distance 0.9670756459236145
# Nearest neighbor 2: 1733, WX-P Distance 0.9611263275146484
# Nearest neighbor 3: 1714, WX-P Distance 0.960403561592102
# Nearest neighbor 4: 1816, WX-P Distance 0.9583081007003784
# Nearest neighbor 5: 1764, WX-P Distance 0.9578195214271545
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1774, WX-P Distance 0.9592539072036743
# Nearest neighbor 2: 1725, WX-P Distance 0.9451934099197388
# Nearest neighbor 3: 1851, WX-P Distance 0.943156361579895
# Nearest neighbor 4: 1569, WX-P Distance 0.9414114952087402
# Nearest neighbor 5: 1574, WX-P Distance 0.9408113360404968
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1624, WX-P Distance 0.9692716598510742
# Nearest neighbor 2: 1570, WX-P Distance 0.964163064956665
# Nearest neighbor 3: 1523, WX-P Distance 0.9598726630210876
# Nearest neighbor 4: 1559, WX-P Distance 0.959803581237793
# Nearest neighbor 5: 1779, WX-P Distance 0.9556716084480286
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1805, WX-P Distance 0.9351656436920166
# Nearest neighbor 2: 1695, WX-P Distance 0.934413492679596
# Nearest neighbor 3: 1553, WX-P Distance 0.9276019930839539
# Nearest neighbor 4: 1791, WX-P Distance 0.9265725612640381
# Nearest neighbor 5: 1583, WX-P Distance 0.9262329936027527
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1622, WX-P Distance 0.9344689249992371
# Nearest neighbor 2: 1830, WX-P Distance 0.9327463507652283
# Nearest neighbor 3: 1607, WX-P Distance 0.9322757720947266
# Nearest neighbor 4: 1511, WX-P Distance 0.9308121204376221
# Nearest neighbor 5: 1780, WX-P Distance 0.92889803647995
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1571, WX-P Distance 0.9529094099998474
# Nearest neighbor 2: 1689, WX-P Distance 0.9528442025184631
# Nearest neighbor 3: 1635, WX-P Distance 0.9520585536956787
# Nearest neighbor 4: 1608, WX-P Distance 0.9519795179367065
# Nearest neighbor 5: 1719, WX-P Distance 0.9509236812591553
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1517, WX-P Distance 0.9647371768951416
# Nearest neighbor 2: 1665, WX-P Distance 0.9489288330078125
# Nearest neighbor 3: 1784, WX-P Distance 0.9451810121536255
# Nearest neighbor 4: 1795, WX-P Distance 0.9447845220565796
# Nearest neighbor 5: 1521, WX-P Distance 0.9424107074737549
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1584, WX-P Distance 0.9592209458351135
# Nearest neighbor 2: 1628, WX-P Distance 0.9589066505432129
# Nearest neighbor 3: 1594, WX-P Distance 0.9537031650543213
# Nearest neighbor 4: 1540, WX-P Distance 0.9518542289733887
# Nearest neighbor 5: 1694, WX-P Distance 0.9503104090690613
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1838, WX-P Distance 0.9617167115211487
# Nearest neighbor 2: 1784, WX-P Distance 0.9614845514297485
# Nearest neighbor 3: 1540, WX-P Distance 0.9583866596221924
# Nearest neighbor 4: 1657, WX-P Distance 0.9564744234085083
# Nearest neighbor 5: 1576, WX-P Distance 0.9541836977005005
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1658, WX-P Distance 0.9625067710876465
# Nearest neighbor 2: 1773, WX-P Distance 0.958777666091919
# Nearest neighbor 3: 1665, WX-P Distance 0.9502135515213013
# Nearest neighbor 4: 1545, WX-P Distance 0.9479120969772339
# Nearest neighbor 5: 1540, WX-P Distance 0.937839150428772
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1794, WX-P Distance 0.9667983651161194
# Nearest neighbor 2: 1837, WX-P Distance 0.9565131068229675
# Nearest neighbor 3: 1718, WX-P Distance 0.9544238448143005
# Nearest neighbor 4: 1781, WX-P Distance 0.953143835067749
# Nearest neighbor 5: 1511, WX-P Distance 0.9519450664520264
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1511, WX-P Distance 0.9448651075363159
# Nearest neighbor 2: 1657, WX-P Distance 0.9434713125228882
# Nearest neighbor 3: 1838, WX-P Distance 0.9428978562355042
# Nearest neighbor 4: 1540, WX-P Distance 0.9423173069953918
# Nearest neighbor 5: 1784, WX-P Distance 0.9413537979125977
# most common label was WX-P which == original label WX-P
# Nearest neighbor 1: 1567, WX-P Distance 0.9516406059265137
# Nearest neighbor 2: 1720, WX-P Distance 0.9507006406784058
# Nearest neighbor 3: 1809, WX-P Distance 0.9471985101699829
# Nearest neighbor 4: 1635, WX-P Distance 0.9464998245239258
# Nearest neighbor 5: 1553, WX-P Distance 0.9461150169372559
# most common label was WX-P which == original label WX-P
# ...
# Nearest neighbor 3: 3867, -B Distance 0.9709093570709229
# Nearest neighbor 4: 3897, -B Distance 0.9708266854286194
# Nearest neighbor 5: 3889, -B Distance 0.9698013663291931
# most common label was -B which == original label -B
# Nearest neighbor 1: 3904, -B Distance 0.9707387685775757
# Nearest neighbor 2: 3878, -B Distance 0.9675242900848389
# Nearest neighbor 3: 3909, -B Distance 0.9656476378440857
# Nearest neighbor 4: 3836, -B Distance 0.9604787826538086
# Nearest neighbor 5: 3849, -B Distance 0.9578800797462463
# most common label was -B which == original label -B
# Nearest neighbor 1: 3904, -B Distance 0.9775406718254089
# Nearest neighbor 2: 3878, -B Distance 0.9756439328193665
# Nearest neighbor 3: 3909, -B Distance 0.9750361442565918
# Nearest neighbor 4: 3836, -B Distance 0.9730751514434814
# Nearest neighbor 5: 3899, -B Distance 0.96993088722229
# most common label was -B which == original label -B
# Nearest neighbor 1: 3857, -B Distance 0.903070867061615
# Nearest neighbor 2: 3908, -B Distance 0.898513674736023
# Nearest neighbor 3: 173, KR-L Distance 0.896291196346283
# Nearest neighbor 4: 3882, -B Distance 0.8955413103103638
# Nearest neighbor 5: 3915, -B Distance 0.8941874504089355
# most common label was -B which == original label -B
# Nearest neighbor 1: 3843, -B Distance 0.9652149677276611
# Nearest neighbor 2: 3878, -B Distance 0.9640635251998901
# Nearest neighbor 3: 3899, -B Distance 0.9637647867202759
# Nearest neighbor 4: 3893, -B Distance 0.9626829028129578
# Nearest neighbor 5: 3844, -B Distance 0.962417721748352
# most common label was -B which == original label -B
# Nearest neighbor 1: 3843, -B Distance 0.9761466383934021
# Nearest neighbor 2: 3859, -B Distance 0.9756760597229004
# Nearest neighbor 3: 3893, -B Distance 0.9737198352813721
# Nearest neighbor 4: 3883, -B Distance 0.9575673937797546
# Nearest neighbor 5: 3890, -B Distance 0.9566094875335693
# most common label was -B which == original label -B
# Nearest neighbor 1: 3909, -B Distance 0.9611017107963562
# Nearest neighbor 2: 3852, -B Distance 0.9585580229759216
# Nearest neighbor 3: 3828, -B Distance 0.955145001411438
# Nearest neighbor 4: 3904, -B Distance 0.9505741596221924
# Nearest neighbor 5: 3878, -B Distance 0.9504047632217407
# most common label was -B which == original label -B
# Nearest neighbor 1: 3904, -B Distance 0.976435661315918
# Nearest neighbor 2: 3909, -B Distance 0.9671505689620972
# Nearest neighbor 3: 3878, -B Distance 0.9593777656555176
# Nearest neighbor 4: 3844, -B Distance 0.9567870497703552
# Nearest neighbor 5: 3899, -B Distance 0.955153226852417
# most common label was -B which == original label -B
# Nearest neighbor 1: 3852, -B Distance 0.9639632701873779
# Nearest neighbor 2: 3909, -B Distance 0.9557361602783203
# Nearest neighbor 3: 3904, -B Distance 0.9527832269668579
# Nearest neighbor 4: 3899, -B Distance 0.9516928195953369
# Nearest neighbor 5: 3828, -B Distance 0.9513207077980042
# most common label was -B which == original label -B
# Nearest neighbor 1: 3836, -B Distance 0.9267617464065552
# Nearest neighbor 2: 3882, -B Distance 0.9255694150924683
# Nearest neighbor 3: 3826, -B Distance 0.9245923757553101
# Nearest neighbor 4: 3879, -B Distance 0.9206565618515015
# Nearest neighbor 5: 3900, -B Distance 0.9154943227767944
# most common label was -B which == original label -B
# Nearest neighbor 1: 3844, -B Distance 0.9743621945381165
# Nearest neighbor 2: 3904, -B Distance 0.9725584983825684
# Nearest neighbor 3: 3828, -B Distance 0.9714102745056152
# Nearest neighbor 4: 3878, -B Distance 0.9710144400596619
# Nearest neighbor 5: 3909, -B Distance 0.9681686162948608
# most common label was -B which == original label -B
# Nearest neighbor 1: 3933, Y-GL Distance 0.9463353753089905
# Nearest neighbor 2: 4039, Y-GL Distance 0.940446138381958
# Nearest neighbor 3: 3935, Y-GL Distance 0.9354713559150696
# Nearest neighbor 4: 4012, Y-GL Distance 0.9351760745048523
# Nearest neighbor 5: 503, O-LW Distance 0.9273600578308105
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4022, Y-GL Distance 0.9267202615737915
# Nearest neighbor 2: 3930, Y-GL Distance 0.9194974899291992
# Nearest neighbor 3: 3928, Y-GL Distance 0.9030526876449585
# Nearest neighbor 4: 3957, Y-GL Distance 0.9026575684547424
# Nearest neighbor 5: 4002, Y-GL Distance 0.898497462272644
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3952, Y-GL Distance 0.9261326789855957
# Nearest neighbor 2: 3996, Y-GL Distance 0.9247984886169434
# Nearest neighbor 3: 3941, Y-GL Distance 0.9222915768623352
# Nearest neighbor 4: 3948, Y-GL Distance 0.9172394871711731
# Nearest neighbor 5: 3955, Y-GL Distance 0.9166480302810669
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3947, Y-GL Distance 0.9445902109146118
# Nearest neighbor 2: 3990, Y-GL Distance 0.9441171288490295
# Nearest neighbor 3: 4042, Y-GL Distance 0.9415083527565002
# Nearest neighbor 4: 3953, Y-GL Distance 0.9413933753967285
# Nearest neighbor 5: 3963, Y-GL Distance 0.9405124187469482
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4042, Y-GL Distance 0.951910138130188
# Nearest neighbor 2: 3987, Y-GL Distance 0.9513483047485352
# Nearest neighbor 3: 4004, Y-GL Distance 0.9512761831283569
# Nearest neighbor 4: 3947, Y-GL Distance 0.9508220553398132
# Nearest neighbor 5: 3167, B- Distance 0.9482308626174927
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4014, Y-GL Distance 0.9380019903182983
# Nearest neighbor 2: 4019, Y-GL Distance 0.9246228337287903
# Nearest neighbor 3: 4036, Y-GL Distance 0.9239040613174438
# Nearest neighbor 4: 4001, Y-GL Distance 0.9238300323486328
# Nearest neighbor 5: 3994, Y-GL Distance 0.9204274415969849
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3987, Y-GL Distance 0.9555556178092957
# Nearest neighbor 2: 4042, Y-GL Distance 0.9528619647026062
# Nearest neighbor 3: 3953, Y-GL Distance 0.9487659931182861
# Nearest neighbor 4: 3958, Y-GL Distance 0.9480689167976379
# Nearest neighbor 5: 3997, Y-GL Distance 0.9438853859901428
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4000, Y-GL Distance 0.9461221098899841
# Nearest neighbor 2: 4015, Y-GL Distance 0.9335823059082031
# Nearest neighbor 3: 3951, Y-GL Distance 0.9244363307952881
# Nearest neighbor 4: 3978, Y-GL Distance 0.9217358231544495
# Nearest neighbor 5: 3989, Y-GL Distance 0.9214640259742737
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4000, Y-GL Distance 0.9223653078079224
# Nearest neighbor 2: 3928, Y-GL Distance 0.9180133938789368
# Nearest neighbor 3: 3938, Y-GL Distance 0.9104803800582886
# Nearest neighbor 4: 4028, Y-GL Distance 0.9090471863746643
# Nearest neighbor 5: 3964, Y-GL Distance 0.9087992310523987
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4008, Y-GL Distance 0.9480421543121338
# Nearest neighbor 2: 3995, Y-GL Distance 0.9432708024978638
# Nearest neighbor 3: 3537, B- Distance 0.9311752319335938
# Nearest neighbor 4: 3934, Y-GL Distance 0.9309949278831482
# Nearest neighbor 5: 791, L-MB Distance 0.9308526515960693
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3933, Y-GL Distance 0.951609194278717
# Nearest neighbor 2: 3975, Y-GL Distance 0.9395934343338013
# Nearest neighbor 3: 3986, Y-GL Distance 0.9376124739646912
# Nearest neighbor 4: 3924, Y-GL Distance 0.9306162595748901
# Nearest neighbor 5: 3977, Y-GL Distance 0.9292033910751343
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3930, Y-GL Distance 0.9243628978729248
# Nearest neighbor 2: 4012, Y-GL Distance 0.9126133918762207
# Nearest neighbor 3: 4002, Y-GL Distance 0.9107071757316589
# Nearest neighbor 4: 4003, Y-GL Distance 0.9083464741706848
# Nearest neighbor 5: 3928, Y-GL Distance 0.9071905016899109
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 547, O-LW Distance 0.9286841154098511
# Nearest neighbor 2: 4009, Y-GL Distance 0.9193149209022522
# Nearest neighbor 3: 3055, B- Distance 0.909727156162262
# Nearest neighbor 4: 3965, Y-GL Distance 0.9043015241622925
# Nearest neighbor 5: 2676, B- Distance 0.8987076282501221
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3957, Y-GL Distance 0.9294118285179138
# Nearest neighbor 2: 3930, Y-GL Distance 0.9040064811706543
# Nearest neighbor 3: 4022, Y-GL Distance 0.8990025520324707
# Nearest neighbor 4: 4020, Y-GL Distance 0.8936172723770142
# Nearest neighbor 5: 4002, Y-GL Distance 0.8931386470794678
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3934, Y-GL Distance 0.9647491574287415
# Nearest neighbor 2: 3950, Y-GL Distance 0.9514338374137878
# Nearest neighbor 3: 3995, Y-GL Distance 0.9498649835586548
# Nearest neighbor 4: 910, L-MB Distance 0.9469513893127441
# Nearest neighbor 5: 4026, Y-GL Distance 0.9406769871711731
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3928, Y-GL Distance 0.9242134690284729
# Nearest neighbor 2: 4000, Y-GL Distance 0.9178054332733154
# Nearest neighbor 3: 4007, Y-GL Distance 0.9166150689125061
# Nearest neighbor 4: 3964, Y-GL Distance 0.9146983623504639
# Nearest neighbor 5: 3948, Y-GL Distance 0.9136462807655334
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3950, Y-GL Distance 0.9522416591644287
# Nearest neighbor 2: 2945, B- Distance 0.9438873529434204
# Nearest neighbor 3: 3523, B- Distance 0.9392130970954895
# Nearest neighbor 4: 3450, B- Distance 0.9391392469406128
# Nearest neighbor 5: 2506, B- Distance 0.9389300346374512
# most common label was B- which != Y-GL
# Nearest neighbor 1: 3922, Y-GL Distance 0.9540771842002869
# Nearest neighbor 2: 392, W-GL Distance 0.9454708695411682
# Nearest neighbor 3: 906, L-MB Distance 0.9394106268882751
# Nearest neighbor 4: 787, L-MB Distance 0.9363272786140442
# Nearest neighbor 5: 424, W-GL Distance 0.934153139591217
# most common label was W-GL which != Y-GL
# Nearest neighbor 1: 3930, Y-GL Distance 0.9235758185386658
# Nearest neighbor 2: 3957, Y-GL Distance 0.9080803394317627
# Nearest neighbor 3: 4029, Y-GL Distance 0.906489372253418
# Nearest neighbor 4: 3784, B- Distance 0.9062563180923462
# Nearest neighbor 5: 4043, Y-GL Distance 0.9034773707389832
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3948, Y-GL Distance 0.9554899334907532
# Nearest neighbor 2: 3965, Y-GL Distance 0.9368717074394226
# Nearest neighbor 3: 3975, Y-GL Distance 0.9319088459014893
# Nearest neighbor 4: 4003, Y-GL Distance 0.9288026094436646
# Nearest neighbor 5: 4028, Y-GL Distance 0.9268795251846313
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3924, Y-GL Distance 0.9371443390846252
# Nearest neighbor 2: 540, O-LW Distance 0.9357422590255737
# Nearest neighbor 3: 3969, Y-GL Distance 0.9325191974639893
# Nearest neighbor 4: 3562, B- Distance 0.9323520660400391
# Nearest neighbor 5: 3233, B- Distance 0.9322952032089233
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 540, O-LW Distance 0.9309545755386353
# Nearest neighbor 2: 3945, Y-GL Distance 0.9309127926826477
# Nearest neighbor 3: 3924, Y-GL Distance 0.9303491115570068
# Nearest neighbor 4: 544, O-LW Distance 0.9263367652893066
# Nearest neighbor 5: 4009, Y-GL Distance 0.9258140921592712
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4014, Y-GL Distance 0.9433043003082275
# Nearest neighbor 2: 4036, Y-GL Distance 0.9349037408828735
# Nearest neighbor 3: 3933, Y-GL Distance 0.9303656816482544
# Nearest neighbor 4: 4001, Y-GL Distance 0.9276840686798096
# Nearest neighbor 5: 500, O-LW Distance 0.9259638786315918
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4028, Y-GL Distance 0.9189210534095764
# Nearest neighbor 2: 3928, Y-GL Distance 0.9171938896179199
# Nearest neighbor 3: 3921, Y-GL Distance 0.9086582660675049
# Nearest neighbor 4: 4021, Y-GL Distance 0.9040158987045288
# Nearest neighbor 5: 3978, Y-GL Distance 0.9020223617553711
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4042, Y-GL Distance 0.9585621953010559
# Nearest neighbor 2: 2461, B- Distance 0.9575787782669067
# Nearest neighbor 3: 3987, Y-GL Distance 0.9539223909378052
# Nearest neighbor 4: 3958, Y-GL Distance 0.9535060524940491
# Nearest neighbor 5: 3697, B- Distance 0.9506551623344421
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4000, Y-GL Distance 0.9246951341629028
# Nearest neighbor 2: 3928, Y-GL Distance 0.919392466545105
# Nearest neighbor 3: 3964, Y-GL Distance 0.9172070026397705
# Nearest neighbor 4: 3001, B- Distance 0.9104691743850708
# Nearest neighbor 5: 3996, Y-GL Distance 0.9092316627502441
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4026, Y-GL Distance 0.9627742767333984
# Nearest neighbor 2: 4008, Y-GL Distance 0.9580698013305664
# Nearest neighbor 3: 3228, B- Distance 0.9470179080963135
# Nearest neighbor 4: 3934, Y-GL Distance 0.9463853240013123
# Nearest neighbor 5: 3251, B- Distance 0.9457606673240662
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4012, Y-GL Distance 0.9119884371757507
# Nearest neighbor 2: 2806, B- Distance 0.9085373282432556
# Nearest neighbor 3: 2239, B- Distance 0.9080221652984619
# Nearest neighbor 4: 3140, B- Distance 0.9051081538200378
# Nearest neighbor 5: 3196, B- Distance 0.9044357538223267
# most common label was B- which != Y-GL
# Nearest neighbor 1: 3996, Y-GL Distance 0.9448714256286621
# Nearest neighbor 2: 4006, Y-GL Distance 0.9399073123931885
# Nearest neighbor 3: 3952, Y-GL Distance 0.9338831901550293
# Nearest neighbor 4: 3926, Y-GL Distance 0.9287207126617432
# Nearest neighbor 5: 3001, B- Distance 0.9263988137245178
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4036, Y-GL Distance 0.9423810243606567
# Nearest neighbor 2: 3950, Y-GL Distance 0.9386935830116272
# Nearest neighbor 3: 4014, Y-GL Distance 0.9371135830879211
# Nearest neighbor 4: 4004, Y-GL Distance 0.9352576732635498
# Nearest neighbor 5: 3241, B- Distance 0.9279865026473999
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3933, Y-GL Distance 0.9614189863204956
# Nearest neighbor 2: 4010, Y-GL Distance 0.95599365234375
# Nearest neighbor 3: 3924, Y-GL Distance 0.9407899379730225
# Nearest neighbor 4: 4035, Y-GL Distance 0.939207136631012
# Nearest neighbor 5: 3970, Y-GL Distance 0.9363178014755249
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 4042, Y-GL Distance 0.9551868438720703
# Nearest neighbor 2: 3950, Y-GL Distance 0.9539960622787476
# Nearest neighbor 3: 3934, Y-GL Distance 0.9522734880447388
# Nearest neighbor 4: 3963, Y-GL Distance 0.9446322917938232
# Nearest neighbor 5: 3947, Y-GL Distance 0.9426360726356506
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3950, Y-GL Distance 0.9689843654632568
# Nearest neighbor 2: 4042, Y-GL Distance 0.955686092376709
# Nearest neighbor 3: 4026, Y-GL Distance 0.9508275389671326
# Nearest neighbor 4: 3963, Y-GL Distance 0.9487252831459045
# Nearest neighbor 5: 3987, Y-GL Distance 0.9430695176124573
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3950, Y-GL Distance 0.9640563726425171
# Nearest neighbor 2: 4026, Y-GL Distance 0.9631718397140503
# Nearest neighbor 3: 4042, Y-GL Distance 0.9555727243423462
# Nearest neighbor 4: 3995, Y-GL Distance 0.9525750875473022
# Nearest neighbor 5: 3934, Y-GL Distance 0.9523177742958069
# most common label was Y-GL which == original label Y-GL
# Nearest neighbor 1: 3960, Y-GL Distance 0.9343374967575073
# Nearest neighbor 2: 774, L-MB Distance 0.9261237382888794
# Nearest neighbor 3: 3471, B- Distance 0.9257537126541138
# Nearest neighbor 4: 3380, B- Distance 0.924673318862915
# Nearest neighbor 5: 2481, B- Distance 0.9240318536758423
# most common label was B- which != Y-GL
# Total accuracy: 0.948892674616695
# Median of all distances: 0.9503642916679382
# Median distance of incorrect guesses: 0.9214431047439575
# Median distance of correct guesses: 0.9510117769241333
# Lowest: 0.8466432094573975 highest: 0.9811556339263916

# %%
def get_last_id(files):
  return files[-1]['id']

# %%
# !rsync -a --info=progress2 "drive/MyDrive/Datasets/masked-Dataset_C.zip" "./"
import zipfile
with zipfile.ZipFile("masked-Dataset_C.zip", 'r') as zip_ref:
    zip_ref.extractall("./dataset-C/")
# Out:
#     101,083,341 100%   95.70MB/s    0:00:01 (xfr#1, to-chk=0/1)

# %%
id = get_last_id(files) + 1
val_dataset = generate_dict_from_set("./dataset-C/", id)
majority_voting_cosine(faiss_index, files, val_dataset)
# Out:
#   0%|          | 0/5218 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Nearest neighbor 4: 249, K-WP Distance 0.3266324996948242
# Nearest neighbor 5: 219, K-WP Distance 0.3274573087692261
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 2420, L-MB Distance 0.2996430993080139
# Nearest neighbor 2: 219, K-WP Distance 0.3333553969860077
# Nearest neighbor 3: 1661, MO-R Distance 0.339150071144104
# Nearest neighbor 4: 1592, MO-R Distance 0.33993667364120483
# Nearest neighbor 5: 1588, MO-R Distance 0.3426821529865265
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1539, MO-R Distance 0.24571216106414795
# Nearest neighbor 2: 1466, MO-R Distance 0.2665947675704956
# Nearest neighbor 3: 1574, MO-R Distance 0.26817822456359863
# Nearest neighbor 4: 1513, MO-R Distance 0.2695402204990387
# Nearest neighbor 5: 1628, MO-R Distance 0.2713768482208252
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.3646027445793152
# Nearest neighbor 2: 432, -Y Distance 0.3881685435771942
# Nearest neighbor 3: 168, K-WP Distance 0.3958030045032501
# Nearest neighbor 4: 167, K-WP Distance 0.4000634551048279
# Nearest neighbor 5: 157, K-WP Distance 0.40123406052589417
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1414, MO-R Distance 0.24528369307518005
# Nearest neighbor 2: 1377, MO-R Distance 0.2693479061126709
# Nearest neighbor 3: 1552, MO-R Distance 0.27209267020225525
# Nearest neighbor 4: 1673, MO-R Distance 0.27992022037506104
# Nearest neighbor 5: 1578, MO-R Distance 0.28774821758270264
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1414, MO-R Distance 0.3079541325569153
# Nearest neighbor 2: 1574, MO-R Distance 0.33074289560317993
# Nearest neighbor 3: 1539, MO-R Distance 0.3365415930747986
# Nearest neighbor 4: 1557, MO-R Distance 0.33808571100234985
# Nearest neighbor 5: 1552, MO-R Distance 0.3515499532222748
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.36333879828453064
# Nearest neighbor 2: 432, -Y Distance 0.387425035238266
# Nearest neighbor 3: 451, -Y Distance 0.3897736370563507
# Nearest neighbor 4: 846, -Y Distance 0.4124230742454529
# Nearest neighbor 5: 167, K-WP Distance 0.4142700433731079
# most common label was -Y which != RM-X
# Nearest neighbor 1: 1574, MO-R Distance 0.24675151705741882
# Nearest neighbor 2: 1592, MO-R Distance 0.2490020990371704
# Nearest neighbor 3: 1661, MO-R Distance 0.25852659344673157
# Nearest neighbor 4: 1539, MO-R Distance 0.2660852372646332
# Nearest neighbor 5: 1557, MO-R Distance 0.27345341444015503
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.2844546437263489
# Nearest neighbor 2: 167, K-WP Distance 0.2845465838909149
# Nearest neighbor 3: 1661, MO-R Distance 0.3049881160259247
# Nearest neighbor 4: 1574, MO-R Distance 0.32285428047180176
# Nearest neighbor 5: 432, -Y Distance 0.32421451807022095
# most common label was -Y which != RM-X
# Nearest neighbor 1: 1574, MO-R Distance 0.2876031994819641
# Nearest neighbor 2: 1592, MO-R Distance 0.3147541880607605
# Nearest neighbor 3: 168, K-WP Distance 0.31665492057800293
# Nearest neighbor 4: 167, K-WP Distance 0.3174397945404053
# Nearest neighbor 5: 1539, MO-R Distance 0.3357950448989868
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.28983765840530396
# Nearest neighbor 2: 168, K-WP Distance 0.30914825201034546
# Nearest neighbor 3: 157, K-WP Distance 0.3237977921962738
# Nearest neighbor 4: 1533, MO-R Distance 0.34235215187072754
# Nearest neighbor 5: 1588, MO-R Distance 0.3448966145515442
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.4308030605316162
# Nearest neighbor 2: 168, K-WP Distance 0.4355723261833191
# Nearest neighbor 3: 967, -Y Distance 0.4411330819129944
# Nearest neighbor 4: 157, K-WP Distance 0.4532371163368225
# Nearest neighbor 5: 385, -Y Distance 0.46732836961746216
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1672, MO-R Distance 0.27540576457977295
# Nearest neighbor 2: 1579, MO-R Distance 0.27680066227912903
# Nearest neighbor 3: 1574, MO-R Distance 0.2805561423301697
# Nearest neighbor 4: 1414, MO-R Distance 0.28163522481918335
# Nearest neighbor 5: 1427, MO-R Distance 0.28222712874412537
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.28418052196502686
# Nearest neighbor 2: 1574, MO-R Distance 0.291374534368515
# Nearest neighbor 3: 1592, MO-R Distance 0.29645511507987976
# Nearest neighbor 4: 168, K-WP Distance 0.29900264739990234
# Nearest neighbor 5: 219, K-WP Distance 0.3051607310771942
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.2917789816856384
# Nearest neighbor 2: 1574, MO-R Distance 0.3010418713092804
# Nearest neighbor 3: 168, K-WP Distance 0.3143078088760376
# Nearest neighbor 4: 1533, MO-R Distance 0.3158096373081207
# Nearest neighbor 5: 1592, MO-R Distance 0.31665557622909546
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1661, MO-R Distance 0.3503255248069763
# Nearest neighbor 2: 967, -Y Distance 0.35616621375083923
# Nearest neighbor 3: 2420, L-MB Distance 0.3613704741001129
# Nearest neighbor 4: 451, -Y Distance 0.36513423919677734
# Nearest neighbor 5: 167, K-WP Distance 0.36778727173805237
# most common label was -Y which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.40550029277801514
# Nearest neighbor 2: 157, K-WP Distance 0.42862996459007263
# Nearest neighbor 3: 967, -Y Distance 0.43428874015808105
# Nearest neighbor 4: 168, K-WP Distance 0.43609505891799927
# Nearest neighbor 5: 243, K-WP Distance 0.4503422975540161
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 211, K-WP Distance 0.2965710461139679
# Nearest neighbor 2: 225, K-WP Distance 0.3049100339412689
# Nearest neighbor 3: 159, K-WP Distance 0.3065301179885864
# Nearest neighbor 4: 1628, MO-R Distance 0.31114089488983154
# Nearest neighbor 5: 185, K-WP Distance 0.3151026964187622
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.38786953687667847
# Nearest neighbor 2: 168, K-WP Distance 0.4031963348388672
# Nearest neighbor 3: 157, K-WP Distance 0.4130252003669739
# Nearest neighbor 4: 967, -Y Distance 0.42586639523506165
# Nearest neighbor 5: 243, K-WP Distance 0.43150705099105835
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 432, -Y Distance 0.39188915491104126
# Nearest neighbor 2: 967, -Y Distance 0.39410200715065
# Nearest neighbor 3: 846, -Y Distance 0.4244880676269531
# Nearest neighbor 4: 451, -Y Distance 0.4272995591163635
# Nearest neighbor 5: 893, -Y Distance 0.4351699650287628
# most common label was -Y which != RM-X
# Nearest neighbor 1: 1661, MO-R Distance 0.3276485800743103
# Nearest neighbor 2: 167, K-WP Distance 0.3303941488265991
# Nearest neighbor 3: 1574, MO-R Distance 0.33542880415916443
# Nearest neighbor 4: 1533, MO-R Distance 0.34095603227615356
# Nearest neighbor 5: 1592, MO-R Distance 0.3632560968399048
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.36382317543029785
# Nearest neighbor 2: 167, K-WP Distance 0.3638306260108948
# Nearest neighbor 3: 2420, L-MB Distance 0.37603065371513367
# Nearest neighbor 4: 1574, MO-R Distance 0.37762778997421265
# Nearest neighbor 5: 1661, MO-R Distance 0.37804925441741943
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1414, MO-R Distance 0.27428868412971497
# Nearest neighbor 2: 1552, MO-R Distance 0.30121153593063354
# Nearest neighbor 3: 1237, B- Distance 0.30280619859695435
# Nearest neighbor 4: 1543, MO-R Distance 0.31579017639160156
# Nearest neighbor 5: 1466, MO-R Distance 0.3194660544395447
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 168, K-WP Distance 0.3127981126308441
# Nearest neighbor 2: 157, K-WP Distance 0.3209855854511261
# Nearest neighbor 3: 1574, MO-R Distance 0.32615065574645996
# Nearest neighbor 4: 167, K-WP Distance 0.3273768723011017
# Nearest neighbor 5: 1592, MO-R Distance 0.3306499123573303
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 159, K-WP Distance 0.2394816130399704
# Nearest neighbor 2: 1565, MO-R Distance 0.2564876079559326
# Nearest neighbor 3: 215, K-WP Distance 0.25856393575668335
# Nearest neighbor 4: 225, K-WP Distance 0.2745284140110016
# Nearest neighbor 5: 1520, MO-R Distance 0.2755088210105896
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1661, MO-R Distance 0.3542819023132324
# Nearest neighbor 2: 451, -Y Distance 0.36116793751716614
# Nearest neighbor 3: 967, -Y Distance 0.36131057143211365
# Nearest neighbor 4: 432, -Y Distance 0.36523717641830444
# Nearest neighbor 5: 1574, MO-R Distance 0.3662463426589966
# most common label was -Y which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.3743562698364258
# Nearest neighbor 2: 167, K-WP Distance 0.39552929997444153
# Nearest neighbor 3: 432, -Y Distance 0.39800798892974854
# Nearest neighbor 4: 451, -Y Distance 0.39998504519462585
# Nearest neighbor 5: 168, K-WP Distance 0.4072422683238983
# most common label was -Y which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.3953218162059784
# Nearest neighbor 2: 167, K-WP Distance 0.424248069524765
# Nearest neighbor 3: 846, -Y Distance 0.4262583553791046
# Nearest neighbor 4: 893, -Y Distance 0.4324186444282532
# Nearest neighbor 5: 168, K-WP Distance 0.4346306324005127
# most common label was -Y which != RM-X
# Nearest neighbor 1: 1628, MO-R Distance 0.2808086574077606
# Nearest neighbor 2: 1466, MO-R Distance 0.2850630283355713
# Nearest neighbor 3: 1442, MO-R Distance 0.2979007363319397
# Nearest neighbor 4: 1594, MO-R Distance 0.3015790581703186
# Nearest neighbor 5: 1525, MO-R Distance 0.302128404378891
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1377, MO-R Distance 0.2878350615501404
# Nearest neighbor 2: 1673, MO-R Distance 0.2951763868331909
# Nearest neighbor 3: 1378, MO-R Distance 0.29842889308929443
# Nearest neighbor 4: 1557, MO-R Distance 0.30482351779937744
# Nearest neighbor 5: 1414, MO-R Distance 0.3053209185600281
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 168, K-WP Distance 0.2784280478954315
# Nearest neighbor 2: 157, K-WP Distance 0.2811097800731659
# Nearest neighbor 3: 167, K-WP Distance 0.28290891647338867
# Nearest neighbor 4: 225, K-WP Distance 0.29209059476852417
# Nearest neighbor 5: 1409, MO-R Distance 0.2927052080631256
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1414, MO-R Distance 0.30474576354026794
# Nearest neighbor 2: 1552, MO-R Distance 0.3272561728954315
# Nearest neighbor 3: 159, K-WP Distance 0.331159770488739
# Nearest neighbor 4: 1408, MO-R Distance 0.33417731523513794
# Nearest neighbor 5: 1377, MO-R Distance 0.33740779757499695
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1574, MO-R Distance 0.28212618827819824
# Nearest neighbor 2: 167, K-WP Distance 0.2923450469970703
# Nearest neighbor 3: 168, K-WP Distance 0.30459243059158325
# Nearest neighbor 4: 219, K-WP Distance 0.3095856308937073
# Nearest neighbor 5: 1592, MO-R Distance 0.32087236642837524
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 157, K-WP Distance 0.32049375772476196
# Nearest neighbor 2: 168, K-WP Distance 0.32238107919692993
# Nearest neighbor 3: 1539, MO-R Distance 0.32551249861717224
# Nearest neighbor 4: 1557, MO-R Distance 0.32626873254776
# Nearest neighbor 5: 167, K-WP Distance 0.33456963300704956
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 157, K-WP Distance 0.34530526399612427
# Nearest neighbor 2: 168, K-WP Distance 0.3461662828922272
# Nearest neighbor 3: 1574, MO-R Distance 0.3664172887802124
# Nearest neighbor 4: 967, -Y Distance 0.3671739101409912
# Nearest neighbor 5: 1539, MO-R Distance 0.36729592084884644
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 168, K-WP Distance 0.36292004585266113
# Nearest neighbor 2: 1574, MO-R Distance 0.3636394739151001
# Nearest neighbor 3: 167, K-WP Distance 0.36691781878471375
# Nearest neighbor 4: 1533, MO-R Distance 0.3785788416862488
# Nearest neighbor 5: 157, K-WP Distance 0.38492169976234436
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1414, MO-R Distance 0.33246105909347534
# Nearest neighbor 2: 1539, MO-R Distance 0.3621594309806824
# Nearest neighbor 3: 1557, MO-R Distance 0.3624887764453888
# Nearest neighbor 4: 1424, MO-R Distance 0.36674317717552185
# Nearest neighbor 5: 1620, MO-R Distance 0.37483930587768555
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 157, K-WP Distance 0.3117485046386719
# Nearest neighbor 2: 168, K-WP Distance 0.32380029559135437
# Nearest neighbor 3: 207, K-WP Distance 0.33535024523735046
# Nearest neighbor 4: 167, K-WP Distance 0.3390968441963196
# Nearest neighbor 5: 181, K-WP Distance 0.3533620834350586
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1377, MO-R Distance 0.3120044469833374
# Nearest neighbor 2: 1414, MO-R Distance 0.3193054795265198
# Nearest neighbor 3: 1595, MO-R Distance 0.35186201333999634
# Nearest neighbor 4: 1578, MO-R Distance 0.3527538776397705
# Nearest neighbor 5: 1638, MO-R Distance 0.36059504747390747
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1574, MO-R Distance 0.2771300673484802
# Nearest neighbor 2: 1592, MO-R Distance 0.2903890609741211
# Nearest neighbor 3: 167, K-WP Distance 0.3025210499763489
# Nearest neighbor 4: 1661, MO-R Distance 0.3102554380893707
# Nearest neighbor 5: 1494, MO-R Distance 0.32028061151504517
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1574, MO-R Distance 0.3294312357902527
# Nearest neighbor 2: 168, K-WP Distance 0.33960404992103577
# Nearest neighbor 3: 1539, MO-R Distance 0.3425455093383789
# Nearest neighbor 4: 1592, MO-R Distance 0.3431398868560791
# Nearest neighbor 5: 1628, MO-R Distance 0.3540976941585541
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.2289048731327057
# Nearest neighbor 2: 168, K-WP Distance 0.23192444443702698
# Nearest neighbor 3: 157, K-WP Distance 0.26748842000961304
# Nearest neighbor 4: 219, K-WP Distance 0.2717212736606598
# Nearest neighbor 5: 207, K-WP Distance 0.2892189621925354
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1424, MO-R Distance 0.3033800721168518
# Nearest neighbor 2: 1557, MO-R Distance 0.3042132258415222
# Nearest neighbor 3: 1408, MO-R Distance 0.3069002628326416
# Nearest neighbor 4: 1414, MO-R Distance 0.30922964215278625
# Nearest neighbor 5: 1578, MO-R Distance 0.3186761736869812
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.38391727209091187
# Nearest neighbor 2: 432, -Y Distance 0.4119095504283905
# Nearest neighbor 3: 1588, MO-R Distance 0.4303392469882965
# Nearest neighbor 4: 846, -Y Distance 0.4318348169326782
# Nearest neighbor 5: 157, K-WP Distance 0.43524429202079773
# most common label was -Y which != RM-X
# Nearest neighbor 1: 157, K-WP Distance 0.3720097839832306
# Nearest neighbor 2: 1557, MO-R Distance 0.37258052825927734
# Nearest neighbor 3: 1588, MO-R Distance 0.3758954405784607
# Nearest neighbor 4: 168, K-WP Distance 0.39297670125961304
# Nearest neighbor 5: 1539, MO-R Distance 0.40036463737487793
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 219, K-WP Distance 0.28800809383392334
# Nearest neighbor 2: 167, K-WP Distance 0.2919866442680359
# Nearest neighbor 3: 2420, L-MB Distance 0.3217185139656067
# Nearest neighbor 4: 168, K-WP Distance 0.32472464442253113
# Nearest neighbor 5: 157, K-WP Distance 0.33716490864753723
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 211, K-WP Distance 0.30704444646835327
# Nearest neighbor 2: 153, K-WP Distance 0.3171244263648987
# Nearest neighbor 3: 215, K-WP Distance 0.31833162903785706
# Nearest neighbor 4: 1620, MO-R Distance 0.3280118405818939
# Nearest neighbor 5: 1414, MO-R Distance 0.32975733280181885
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1574, MO-R Distance 0.31313666701316833
# Nearest neighbor 2: 1539, MO-R Distance 0.32133615016937256
# Nearest neighbor 3: 1592, MO-R Distance 0.32272183895111084
# Nearest neighbor 4: 1466, MO-R Distance 0.32833102345466614
# Nearest neighbor 5: 451, -Y Distance 0.3395843505859375
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1628, MO-R Distance 0.3081721067428589
# Nearest neighbor 2: 1424, MO-R Distance 0.30862292647361755
# Nearest neighbor 3: 1377, MO-R Distance 0.31195390224456787
# Nearest neighbor 4: 157, K-WP Distance 0.3151777386665344
# Nearest neighbor 5: 1557, MO-R Distance 0.3172611892223358
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 2420, L-MB Distance 0.3301166296005249
# Nearest neighbor 2: 451, -Y Distance 0.3305119276046753
# Nearest neighbor 3: 1574, MO-R Distance 0.33633852005004883
# Nearest neighbor 4: 1588, MO-R Distance 0.3478757441043854
# Nearest neighbor 5: 219, K-WP Distance 0.3522944152355194
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1414, MO-R Distance 0.28989699482917786
# Nearest neighbor 2: 1403, MO-R Distance 0.2908647656440735
# Nearest neighbor 3: 1466, MO-R Distance 0.3011573851108551
# Nearest neighbor 4: 1579, MO-R Distance 0.3189452886581421
# Nearest neighbor 5: 1552, MO-R Distance 0.31972235441207886
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 157, K-WP Distance 0.4257628917694092
# Nearest neighbor 2: 168, K-WP Distance 0.4329890012741089
# Nearest neighbor 3: 1588, MO-R Distance 0.43335631489753723
# Nearest neighbor 4: 1620, MO-R Distance 0.4425581991672516
# Nearest neighbor 5: 1557, MO-R Distance 0.4487186670303345
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.389953076839447
# Nearest neighbor 2: 167, K-WP Distance 0.3930659592151642
# Nearest neighbor 3: 168, K-WP Distance 0.39551353454589844
# Nearest neighbor 4: 157, K-WP Distance 0.40722236037254333
# Nearest neighbor 5: 432, -Y Distance 0.4142126441001892
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 2420, L-MB Distance 0.2905985116958618
# Nearest neighbor 2: 1661, MO-R Distance 0.31100255250930786
# Nearest neighbor 3: 1592, MO-R Distance 0.3123300075531006
# Nearest neighbor 4: 1574, MO-R Distance 0.3174676299095154
# Nearest neighbor 5: 1539, MO-R Distance 0.32347384095191956
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 168, K-WP Distance 0.362354576587677
# Nearest neighbor 2: 157, K-WP Distance 0.3808428645133972
# Nearest neighbor 3: 195, K-WP Distance 0.3859109878540039
# Nearest neighbor 4: 159, K-WP Distance 0.3909296989440918
# Nearest neighbor 5: 167, K-WP Distance 0.4110686182975769
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.30597299337387085
# Nearest neighbor 2: 168, K-WP Distance 0.32924365997314453
# Nearest neighbor 3: 1574, MO-R Distance 0.33711138367652893
# Nearest neighbor 4: 967, -Y Distance 0.35051682591438293
# Nearest neighbor 5: 451, -Y Distance 0.3580780029296875
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1574, MO-R Distance 0.30638086795806885
# Nearest neighbor 2: 167, K-WP Distance 0.3157702386379242
# Nearest neighbor 3: 1592, MO-R Distance 0.3178969621658325
# Nearest neighbor 4: 168, K-WP Distance 0.31895798444747925
# Nearest neighbor 5: 1533, MO-R Distance 0.32187896966934204
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1557, MO-R Distance 0.34075555205345154
# Nearest neighbor 2: 1377, MO-R Distance 0.34359464049339294
# Nearest neighbor 3: 1588, MO-R Distance 0.3450322449207306
# Nearest neighbor 4: 1424, MO-R Distance 0.35588210821151733
# Nearest neighbor 5: 157, K-WP Distance 0.35817328095436096
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1661, MO-R Distance 0.2973322868347168
# Nearest neighbor 2: 219, K-WP Distance 0.3155038356781006
# Nearest neighbor 3: 167, K-WP Distance 0.32572299242019653
# Nearest neighbor 4: 1592, MO-R Distance 0.33658456802368164
# Nearest neighbor 5: 157, K-WP Distance 0.3387685716152191
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.4484834671020508
# Nearest neighbor 2: 167, K-WP Distance 0.46073514223098755
# Nearest neighbor 3: 432, -Y Distance 0.4695844352245331
# Nearest neighbor 4: 771, -Y Distance 0.471127450466156
# Nearest neighbor 5: 157, K-WP Distance 0.4739609956741333
# most common label was -Y which != RM-X
# Nearest neighbor 1: 157, K-WP Distance 0.3358367681503296
# Nearest neighbor 2: 1588, MO-R Distance 0.34048086404800415
# Nearest neighbor 3: 167, K-WP Distance 0.34635305404663086
# Nearest neighbor 4: 168, K-WP Distance 0.3475850820541382
# Nearest neighbor 5: 1574, MO-R Distance 0.34807080030441284
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1378, MO-R Distance 0.2901681363582611
# Nearest neighbor 2: 211, K-WP Distance 0.29640957713127136
# Nearest neighbor 3: 1557, MO-R Distance 0.29820162057876587
# Nearest neighbor 4: 225, K-WP Distance 0.3015631139278412
# Nearest neighbor 5: 168, K-WP Distance 0.3020782768726349
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1574, MO-R Distance 0.24719637632369995
# Nearest neighbor 2: 1592, MO-R Distance 0.26672565937042236
# Nearest neighbor 3: 1539, MO-R Distance 0.271793931722641
# Nearest neighbor 4: 1597, MO-R Distance 0.28667688369750977
# Nearest neighbor 5: 1557, MO-R Distance 0.2886088192462921
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.40038758516311646
# Nearest neighbor 2: 157, K-WP Distance 0.41879668831825256
# Nearest neighbor 3: 167, K-WP Distance 0.41987454891204834
# Nearest neighbor 4: 432, -Y Distance 0.42168036103248596
# Nearest neighbor 5: 451, -Y Distance 0.4274906814098358
# most common label was -Y which != RM-X
# Nearest neighbor 1: 1377, MO-R Distance 0.31236356496810913
# Nearest neighbor 2: 157, K-WP Distance 0.31997841596603394
# Nearest neighbor 3: 1414, MO-R Distance 0.3209207355976105
# Nearest neighbor 4: 1597, MO-R Distance 0.32152101397514343
# Nearest neighbor 5: 1557, MO-R Distance 0.3229430019855499
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 967, -Y Distance 0.3832166790962219
# Nearest neighbor 2: 167, K-WP Distance 0.393295556306839
# Nearest neighbor 3: 168, K-WP Distance 0.39987292885780334
# Nearest neighbor 4: 157, K-WP Distance 0.4145098924636841
# Nearest neighbor 5: 771, -Y Distance 0.4175069332122803
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 1661, MO-R Distance 0.2859913110733032
# Nearest neighbor 2: 1574, MO-R Distance 0.30990296602249146
# Nearest neighbor 3: 1588, MO-R Distance 0.3107946813106537
# Nearest neighbor 4: 219, K-WP Distance 0.3140917718410492
# Nearest neighbor 5: 1592, MO-R Distance 0.3146505355834961
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.3237018883228302
# Nearest neighbor 2: 168, K-WP Distance 0.3382968306541443
# Nearest neighbor 3: 1574, MO-R Distance 0.35719019174575806
# Nearest neighbor 4: 157, K-WP Distance 0.36214563250541687
# Nearest neighbor 5: 1588, MO-R Distance 0.3709307312965393
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 157, K-WP Distance 0.342135488986969
# Nearest neighbor 2: 168, K-WP Distance 0.3555663526058197
# Nearest neighbor 3: 1588, MO-R Distance 0.38236135244369507
# Nearest neighbor 4: 211, K-WP Distance 0.3889051079750061
# Nearest neighbor 5: 167, K-WP Distance 0.3951272964477539
# most common label was K-WP which != RM-X
# Nearest neighbor 1: 167, K-WP Distance 0.26304060220718384
# Nearest neighbor 2: 1574, MO-R Distance 0.27524280548095703
# Nearest neighbor 3: 168, K-WP Distance 0.2881409525871277
# Nearest neighbor 4: 1533, MO-R Distance 0.2923397719860077
# Nearest neighbor 5: 1592, MO-R Distance 0.30726903676986694
# most common label was MO-R which != RM-X
# Nearest neighbor 1: 1586, MO-R Distance 0.2537878155708313
# Nearest neighbor 2: 1539, MO-R Distance 0.25821518898010254
# Nearest neighbor 3: 1588, MO-R Distance 0.2636977434158325
# Nearest neighbor 4: 1647, MO-R Distance 0.2693989872932434
# Nearest neighbor 5: 1592, MO-R Distance 0.2697647511959076
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2621573805809021
# Nearest neighbor 2: 2426, L-MB Distance 0.2663636803627014
# Nearest neighbor 3: 1498, MO-R Distance 0.2786489725112915
# Nearest neighbor 4: 854, -Y Distance 0.28937047719955444
# Nearest neighbor 5: 777, -Y Distance 0.2916383445262909
# most common label was MO-R which != -B
# Nearest neighbor 1: 1586, MO-R Distance 0.24894246459007263
# Nearest neighbor 2: 1539, MO-R Distance 0.25519126653671265
# Nearest neighbor 3: 1615, MO-R Distance 0.26245439052581787
# Nearest neighbor 4: 1647, MO-R Distance 0.26773837208747864
# Nearest neighbor 5: 1557, MO-R Distance 0.2707297205924988
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.2243957668542862
# Nearest neighbor 2: 1539, MO-R Distance 0.23286674916744232
# Nearest neighbor 3: 1586, MO-R Distance 0.24039997160434723
# Nearest neighbor 4: 1557, MO-R Distance 0.2504030764102936
# Nearest neighbor 5: 1452, MO-R Distance 0.2514196038246155
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.2687683701515198
# Nearest neighbor 2: 1557, MO-R Distance 0.27396345138549805
# Nearest neighbor 3: 1539, MO-R Distance 0.3056465983390808
# Nearest neighbor 4: 1452, MO-R Distance 0.3057575225830078
# Nearest neighbor 5: 1578, MO-R Distance 0.3113880753517151
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2627074420452118
# Nearest neighbor 2: 854, -Y Distance 0.27656763792037964
# Nearest neighbor 3: 970, -Y Distance 0.30070760846138
# Nearest neighbor 4: 1569, MO-R Distance 0.30661290884017944
# Nearest neighbor 5: 403, -Y Distance 0.30873069167137146
# most common label was -Y which != -B
# Nearest neighbor 1: 1539, MO-R Distance 0.23756329715251923
# Nearest neighbor 2: 1557, MO-R Distance 0.2430507093667984
# Nearest neighbor 3: 1588, MO-R Distance 0.24689683318138123
# Nearest neighbor 4: 1586, MO-R Distance 0.24848628044128418
# Nearest neighbor 5: 1558, MO-R Distance 0.24873772263526917
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.3086773753166199
# Nearest neighbor 2: 1569, MO-R Distance 0.31223899126052856
# Nearest neighbor 3: 854, -Y Distance 0.3187863230705261
# Nearest neighbor 4: 970, -Y Distance 0.31894996762275696
# Nearest neighbor 5: 1498, MO-R Distance 0.3235589861869812
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2948073744773865
# Nearest neighbor 2: 1498, MO-R Distance 0.2995576858520508
# Nearest neighbor 3: 854, -Y Distance 0.32053428888320923
# Nearest neighbor 4: 1569, MO-R Distance 0.32105201482772827
# Nearest neighbor 5: 2426, L-MB Distance 0.3238024115562439
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2915912866592407
# Nearest neighbor 2: 1588, MO-R Distance 0.29720526933670044
# Nearest neighbor 3: 1452, MO-R Distance 0.29881906509399414
# Nearest neighbor 4: 1557, MO-R Distance 0.3159843981266022
# Nearest neighbor 5: 1609, MO-R Distance 0.3215636610984802
# most common label was MO-R which != -B
# Nearest neighbor 1: 1557, MO-R Distance 0.1946869194507599
# Nearest neighbor 2: 1539, MO-R Distance 0.20988215506076813
# Nearest neighbor 3: 1574, MO-R Distance 0.2220475673675537
# Nearest neighbor 4: 1586, MO-R Distance 0.22933745384216309
# Nearest neighbor 5: 1558, MO-R Distance 0.23381030559539795
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.22322285175323486
# Nearest neighbor 2: 1592, MO-R Distance 0.2602368891239166
# Nearest neighbor 3: 699, -Y Distance 0.27253279089927673
# Nearest neighbor 4: 1509, MO-R Distance 0.2790164351463318
# Nearest neighbor 5: 1498, MO-R Distance 0.28011125326156616
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.25345247983932495
# Nearest neighbor 2: 1557, MO-R Distance 0.2603206932544708
# Nearest neighbor 3: 1539, MO-R Distance 0.2623004615306854
# Nearest neighbor 4: 1586, MO-R Distance 0.27225929498672485
# Nearest neighbor 5: 1647, MO-R Distance 0.27872443199157715
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.24639379978179932
# Nearest neighbor 2: 1539, MO-R Distance 0.2635315954685211
# Nearest neighbor 3: 1592, MO-R Distance 0.264046847820282
# Nearest neighbor 4: 2426, L-MB Distance 0.27284711599349976
# Nearest neighbor 5: 699, -Y Distance 0.2786068618297577
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.22544541954994202
# Nearest neighbor 2: 1592, MO-R Distance 0.2393714189529419
# Nearest neighbor 3: 1574, MO-R Distance 0.26602914929389954
# Nearest neighbor 4: 1498, MO-R Distance 0.2665014863014221
# Nearest neighbor 5: 1557, MO-R Distance 0.27517178654670715
# most common label was MO-R which != -B
# Nearest neighbor 1: 1633, MO-R Distance 0.3580785393714905
# Nearest neighbor 2: 1466, MO-R Distance 0.3746492266654968
# Nearest neighbor 3: 1672, MO-R Distance 0.3784112334251404
# Nearest neighbor 4: 1380, MO-R Distance 0.3785938024520874
# Nearest neighbor 5: 1513, MO-R Distance 0.38555029034614563
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.23815003037452698
# Nearest neighbor 2: 1592, MO-R Distance 0.24393092095851898
# Nearest neighbor 3: 1574, MO-R Distance 0.24710533022880554
# Nearest neighbor 4: 1557, MO-R Distance 0.26146742701530457
# Nearest neighbor 5: 1586, MO-R Distance 0.2718295156955719
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.34619125723838806
# Nearest neighbor 2: 307, -Y Distance 0.3579041063785553
# Nearest neighbor 3: 395, -Y Distance 0.3675065040588379
# Nearest neighbor 4: 892, -Y Distance 0.3692454993724823
# Nearest neighbor 5: 507, -Y Distance 0.3699478507041931
# most common label was -Y which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2701358199119568
# Nearest neighbor 2: 1592, MO-R Distance 0.2862994968891144
# Nearest neighbor 3: 1539, MO-R Distance 0.2975887060165405
# Nearest neighbor 4: 1452, MO-R Distance 0.29812145233154297
# Nearest neighbor 5: 1574, MO-R Distance 0.2981431782245636
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2809520363807678
# Nearest neighbor 2: 854, -Y Distance 0.28278660774230957
# Nearest neighbor 3: 2426, L-MB Distance 0.2886233627796173
# Nearest neighbor 4: 537, -Y Distance 0.2985715866088867
# Nearest neighbor 5: 1592, MO-R Distance 0.2998923063278198
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.22584031522274017
# Nearest neighbor 2: 1661, MO-R Distance 0.23112355172634125
# Nearest neighbor 3: 1557, MO-R Distance 0.2400207370519638
# Nearest neighbor 4: 1539, MO-R Distance 0.24351352453231812
# Nearest neighbor 5: 1586, MO-R Distance 0.24456997215747833
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2500247061252594
# Nearest neighbor 2: 2426, L-MB Distance 0.276074081659317
# Nearest neighbor 3: 1569, MO-R Distance 0.27836477756500244
# Nearest neighbor 4: 403, -Y Distance 0.2849365174770355
# Nearest neighbor 5: 854, -Y Distance 0.2886991500854492
# most common label was MO-R which != -B
# Nearest neighbor 1: 2426, L-MB Distance 0.33868324756622314
# Nearest neighbor 2: 542, -Y Distance 0.34076595306396484
# Nearest neighbor 3: 1661, MO-R Distance 0.342876136302948
# Nearest neighbor 4: 970, -Y Distance 0.3429541289806366
# Nearest neighbor 5: 699, -Y Distance 0.35815998911857605
# most common label was -Y which != -B
# Nearest neighbor 1: 1539, MO-R Distance 0.22490157186985016
# Nearest neighbor 2: 1557, MO-R Distance 0.2610606849193573
# Nearest neighbor 3: 1586, MO-R Distance 0.261512815952301
# Nearest neighbor 4: 1574, MO-R Distance 0.26513078808784485
# Nearest neighbor 5: 1592, MO-R Distance 0.269146203994751
# most common label was MO-R which != -B
# Nearest neighbor 1: 1574, MO-R Distance 0.23005402088165283
# Nearest neighbor 2: 1557, MO-R Distance 0.23261785507202148
# Nearest neighbor 3: 1592, MO-R Distance 0.23281246423721313
# Nearest neighbor 4: 1539, MO-R Distance 0.23721107840538025
# Nearest neighbor 5: 1661, MO-R Distance 0.24268493056297302
# most common label was MO-R which != -B
# Nearest neighbor 1: 1414, MO-R Distance 0.24394889175891876
# Nearest neighbor 2: 1557, MO-R Distance 0.25888633728027344
# Nearest neighbor 3: 1578, MO-R Distance 0.2646242678165436
# Nearest neighbor 4: 1377, MO-R Distance 0.2666172981262207
# Nearest neighbor 5: 1066, LM-G Distance 0.27219194173812866
# most common label was MO-R which != -B
# Nearest neighbor 1: 1539, MO-R Distance 0.26101505756378174
# Nearest neighbor 2: 1557, MO-R Distance 0.2678546905517578
# Nearest neighbor 3: 1661, MO-R Distance 0.2790747284889221
# Nearest neighbor 4: 1588, MO-R Distance 0.29429689049720764
# Nearest neighbor 5: 1609, MO-R Distance 0.29884982109069824
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2950533628463745
# Nearest neighbor 2: 854, -Y Distance 0.3002711236476898
# Nearest neighbor 3: 970, -Y Distance 0.31554731726646423
# Nearest neighbor 4: 403, -Y Distance 0.31881043314933777
# Nearest neighbor 5: 1592, MO-R Distance 0.3208426237106323
# most common label was -Y which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.33449792861938477
# Nearest neighbor 2: 1557, MO-R Distance 0.33824294805526733
# Nearest neighbor 3: 1539, MO-R Distance 0.3422780930995941
# Nearest neighbor 4: 1452, MO-R Distance 0.3514706492424011
# Nearest neighbor 5: 1661, MO-R Distance 0.36088886857032776
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.2629573941230774
# Nearest neighbor 2: 1557, MO-R Distance 0.26714107394218445
# Nearest neighbor 3: 1586, MO-R Distance 0.28158649802207947
# Nearest neighbor 4: 1539, MO-R Distance 0.28298765420913696
# Nearest neighbor 5: 1452, MO-R Distance 0.2861572802066803
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.26181191205978394
# Nearest neighbor 2: 1569, MO-R Distance 0.2710000276565552
# Nearest neighbor 3: 1539, MO-R Distance 0.27300846576690674
# Nearest neighbor 4: 1586, MO-R Distance 0.27388879656791687
# Nearest neighbor 5: 699, -Y Distance 0.2764212191104889
# most common label was MO-R which != -B
# Nearest neighbor 1: 1466, MO-R Distance 0.2652508020401001
# Nearest neighbor 2: 1539, MO-R Distance 0.2689139246940613
# Nearest neighbor 3: 1414, MO-R Distance 0.2693932056427002
# Nearest neighbor 4: 1557, MO-R Distance 0.29060062766075134
# Nearest neighbor 5: 1578, MO-R Distance 0.2931792736053467
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.22103290259838104
# Nearest neighbor 2: 1592, MO-R Distance 0.24267448484897614
# Nearest neighbor 3: 970, -Y Distance 0.2562013864517212
# Nearest neighbor 4: 2426, L-MB Distance 0.26364022493362427
# Nearest neighbor 5: 1539, MO-R Distance 0.2657340168952942
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2258870154619217
# Nearest neighbor 2: 507, -Y Distance 0.27024826407432556
# Nearest neighbor 3: 1609, MO-R Distance 0.27931466698646545
# Nearest neighbor 4: 970, -Y Distance 0.2831994891166687
# Nearest neighbor 5: 278, -Y Distance 0.2861427962779999
# most common label was -Y which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.29446202516555786
# Nearest neighbor 2: 1661, MO-R Distance 0.3108293414115906
# Nearest neighbor 3: 1452, MO-R Distance 0.3159879446029663
# Nearest neighbor 4: 1539, MO-R Distance 0.3207027316093445
# Nearest neighbor 5: 1557, MO-R Distance 0.3219366669654846
# most common label was MO-R which != -B
# Nearest neighbor 1: 1557, MO-R Distance 0.292756050825119
# Nearest neighbor 2: 1588, MO-R Distance 0.30110952258110046
# Nearest neighbor 3: 1539, MO-R Distance 0.32317090034484863
# Nearest neighbor 4: 1452, MO-R Distance 0.33813709020614624
# Nearest neighbor 5: 1578, MO-R Distance 0.34618112444877625
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.3021220564842224
# Nearest neighbor 2: 1661, MO-R Distance 0.30248165130615234
# Nearest neighbor 3: 1498, MO-R Distance 0.3091791868209839
# Nearest neighbor 4: 1452, MO-R Distance 0.3102765679359436
# Nearest neighbor 5: 1592, MO-R Distance 0.3152877390384674
# most common label was MO-R which != -B
# Nearest neighbor 1: 2426, L-MB Distance 0.3020484745502472
# Nearest neighbor 2: 1661, MO-R Distance 0.3021118640899658
# Nearest neighbor 3: 970, -Y Distance 0.32703667879104614
# Nearest neighbor 4: 1592, MO-R Distance 0.3282541036605835
# Nearest neighbor 5: 1452, MO-R Distance 0.33226171135902405
# most common label was MO-R which != -B
# Nearest neighbor 1: 1539, MO-R Distance 0.21751835942268372
# Nearest neighbor 2: 1557, MO-R Distance 0.23949626088142395
# Nearest neighbor 3: 1586, MO-R Distance 0.24144040048122406
# Nearest neighbor 4: 1574, MO-R Distance 0.24486961960792542
# Nearest neighbor 5: 1558, MO-R Distance 0.24897228181362152
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.27589350938796997
# Nearest neighbor 2: 970, -Y Distance 0.32610127329826355
# Nearest neighbor 3: 699, -Y Distance 0.3399304747581482
# Nearest neighbor 4: 542, -Y Distance 0.3421292304992676
# Nearest neighbor 5: 854, -Y Distance 0.34396892786026
# most common label was -Y which != -B
# Nearest neighbor 1: 1452, MO-R Distance 0.324487566947937
# Nearest neighbor 2: 1557, MO-R Distance 0.326956182718277
# Nearest neighbor 3: 1539, MO-R Distance 0.33092349767684937
# Nearest neighbor 4: 1588, MO-R Distance 0.33255934715270996
# Nearest neighbor 5: 1661, MO-R Distance 0.33896151185035706
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.28468865156173706
# Nearest neighbor 2: 1557, MO-R Distance 0.2989021837711334
# Nearest neighbor 3: 1661, MO-R Distance 0.3015270233154297
# Nearest neighbor 4: 1452, MO-R Distance 0.3157079219818115
# Nearest neighbor 5: 1592, MO-R Distance 0.32198482751846313
# most common label was MO-R which != -B
# Nearest neighbor 1: 628, -Y Distance 0.345658540725708
# Nearest neighbor 2: 1661, MO-R Distance 0.3469594120979309
# Nearest neighbor 3: 1494, MO-R Distance 0.35373455286026
# Nearest neighbor 4: 967, -Y Distance 0.35676947236061096
# Nearest neighbor 5: 1574, MO-R Distance 0.36472952365875244
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2503017485141754
# Nearest neighbor 2: 970, -Y Distance 0.2671581506729126
# Nearest neighbor 3: 278, -Y Distance 0.2718360424041748
# Nearest neighbor 4: 699, -Y Distance 0.27805426716804504
# Nearest neighbor 5: 854, -Y Distance 0.2806648313999176
# most common label was -Y which != -B
# Nearest neighbor 1: 1647, MO-R Distance 0.25662481784820557
# Nearest neighbor 2: 895, -Y Distance 0.26724177598953247
# Nearest neighbor 3: 1615, MO-R Distance 0.27070334553718567
# Nearest neighbor 4: 1546, MO-R Distance 0.2732449173927307
# Nearest neighbor 5: 1550, MO-R Distance 0.2750079929828644
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.21862873435020447
# Nearest neighbor 2: 699, -Y Distance 0.24977535009384155
# Nearest neighbor 3: 970, -Y Distance 0.27415674924850464
# Nearest neighbor 4: 1592, MO-R Distance 0.2753238081932068
# Nearest neighbor 5: 403, -Y Distance 0.27712589502334595
# most common label was -Y which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.26769518852233887
# Nearest neighbor 2: 699, -Y Distance 0.2808600664138794
# Nearest neighbor 3: 278, -Y Distance 0.285783052444458
# Nearest neighbor 4: 970, -Y Distance 0.28861430287361145
# Nearest neighbor 5: 854, -Y Distance 0.29634857177734375
# most common label was -Y which != -B
# Nearest neighbor 1: 1574, MO-R Distance 0.23065586388111115
# Nearest neighbor 2: 1586, MO-R Distance 0.23881174623966217
# Nearest neighbor 3: 1557, MO-R Distance 0.24149763584136963
# Nearest neighbor 4: 1539, MO-R Distance 0.2415281981229782
# Nearest neighbor 5: 1592, MO-R Distance 0.24648094177246094
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.28056997060775757
# Nearest neighbor 2: 1661, MO-R Distance 0.2894483804702759
# Nearest neighbor 3: 1557, MO-R Distance 0.29949724674224854
# Nearest neighbor 4: 1574, MO-R Distance 0.3045050799846649
# Nearest neighbor 5: 1539, MO-R Distance 0.308840811252594
# most common label was MO-R which != -B
# Nearest neighbor 1: 1557, MO-R Distance 0.3440764546394348
# Nearest neighbor 2: 1588, MO-R Distance 0.3549974858760834
# Nearest neighbor 3: 1452, MO-R Distance 0.36432385444641113
# Nearest neighbor 4: 1539, MO-R Distance 0.38843563199043274
# Nearest neighbor 5: 1647, MO-R Distance 0.39322221279144287
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.24197420477867126
# Nearest neighbor 2: 970, -Y Distance 0.2581685185432434
# Nearest neighbor 3: 1592, MO-R Distance 0.25973042845726013
# Nearest neighbor 4: 2426, L-MB Distance 0.26554596424102783
# Nearest neighbor 5: 1574, MO-R Distance 0.26999276876449585
# most common label was MO-R which != -B
# Nearest neighbor 1: 1557, MO-R Distance 0.2643575668334961
# Nearest neighbor 2: 1588, MO-R Distance 0.26961496472358704
# Nearest neighbor 3: 1574, MO-R Distance 0.2966776192188263
# Nearest neighbor 4: 1539, MO-R Distance 0.30284583568573
# Nearest neighbor 5: 1592, MO-R Distance 0.3059893846511841
# most common label was MO-R which != -B
# Nearest neighbor 1: 1557, MO-R Distance 0.2213720679283142
# Nearest neighbor 2: 1588, MO-R Distance 0.25368189811706543
# Nearest neighbor 3: 1539, MO-R Distance 0.2610621750354767
# Nearest neighbor 4: 1574, MO-R Distance 0.2619316875934601
# Nearest neighbor 5: 1592, MO-R Distance 0.26847657561302185
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.2691653072834015
# Nearest neighbor 2: 1557, MO-R Distance 0.26990148425102234
# Nearest neighbor 3: 1452, MO-R Distance 0.2863495349884033
# Nearest neighbor 4: 1539, MO-R Distance 0.2947574257850647
# Nearest neighbor 5: 1586, MO-R Distance 0.29944780468940735
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.24831140041351318
# Nearest neighbor 2: 1592, MO-R Distance 0.27908483147621155
# Nearest neighbor 3: 1574, MO-R Distance 0.2840655446052551
# Nearest neighbor 4: 1539, MO-R Distance 0.285088449716568
# Nearest neighbor 5: 699, -Y Distance 0.2935727834701538
# most common label was MO-R which != -B
# Nearest neighbor 1: 1588, MO-R Distance 0.2891163229942322
# Nearest neighbor 2: 1557, MO-R Distance 0.291701078414917
# Nearest neighbor 3: 1452, MO-R Distance 0.30751121044158936
# Nearest neighbor 4: 2426, L-MB Distance 0.3092539310455322
# Nearest neighbor 5: 1592, MO-R Distance 0.31371602416038513
# most common label was MO-R which != -B
# Nearest neighbor 1: 1673, MO-R Distance 0.27395981550216675
# Nearest neighbor 2: 1414, MO-R Distance 0.27799588441848755
# Nearest neighbor 3: 1377, MO-R Distance 0.27936553955078125
# Nearest neighbor 4: 1466, MO-R Distance 0.29024943709373474
# Nearest neighbor 5: 1408, MO-R Distance 0.2922569215297699
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.28038913011550903
# Nearest neighbor 2: 1539, MO-R Distance 0.2902281880378723
# Nearest neighbor 3: 1588, MO-R Distance 0.2911134958267212
# Nearest neighbor 4: 1557, MO-R Distance 0.29152730107307434
# Nearest neighbor 5: 1452, MO-R Distance 0.2917693853378296
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.22626304626464844
# Nearest neighbor 2: 1592, MO-R Distance 0.2479347288608551
# Nearest neighbor 3: 1557, MO-R Distance 0.253092497587204
# Nearest neighbor 4: 1539, MO-R Distance 0.26647233963012695
# Nearest neighbor 5: 1586, MO-R Distance 0.2729288935661316
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.24502259492874146
# Nearest neighbor 2: 1592, MO-R Distance 0.2933662533760071
# Nearest neighbor 3: 699, -Y Distance 0.29707249999046326
# Nearest neighbor 4: 970, -Y Distance 0.3119082450866699
# Nearest neighbor 5: 1574, MO-R Distance 0.3124239444732666
# most common label was MO-R which != -B
# Nearest neighbor 1: 1574, MO-R Distance 0.27783113718032837
# Nearest neighbor 2: 1661, MO-R Distance 0.27868005633354187
# Nearest neighbor 3: 1592, MO-R Distance 0.2811793088912964
# Nearest neighbor 4: 1557, MO-R Distance 0.2823304831981659
# Nearest neighbor 5: 1539, MO-R Distance 0.29076188802719116
# most common label was MO-R which != -B
# Nearest neighbor 1: 1539, MO-R Distance 0.22848466038703918
# Nearest neighbor 2: 1647, MO-R Distance 0.24950581789016724
# Nearest neighbor 3: 1586, MO-R Distance 0.25259608030319214
# Nearest neighbor 4: 1662, MO-R Distance 0.25476235151290894
# Nearest neighbor 5: 1592, MO-R Distance 0.25669753551483154
# most common label was MO-R which != -B
# Nearest neighbor 1: 1586, MO-R Distance 0.27606144547462463
# Nearest neighbor 2: 1539, MO-R Distance 0.27897486090660095
# Nearest neighbor 3: 1498, MO-R Distance 0.2934989333152771
# Nearest neighbor 4: 1588, MO-R Distance 0.29760295152664185
# Nearest neighbor 5: 1557, MO-R Distance 0.3004680573940277
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.24323517084121704
# Nearest neighbor 2: 970, -Y Distance 0.27664828300476074
# Nearest neighbor 3: 699, -Y Distance 0.2793031930923462
# Nearest neighbor 4: 2426, L-MB Distance 0.28415173292160034
# Nearest neighbor 5: 542, -Y Distance 0.2904130518436432
# most common label was -Y which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2689976692199707
# Nearest neighbor 2: 970, -Y Distance 0.2806973159313202
# Nearest neighbor 3: 278, -Y Distance 0.2811232805252075
# Nearest neighbor 4: 967, -Y Distance 0.28531455993652344
# Nearest neighbor 5: 699, -Y Distance 0.28560641407966614
# most common label was -Y which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.22825294733047485
# Nearest neighbor 2: 1592, MO-R Distance 0.2510313093662262
# Nearest neighbor 3: 1557, MO-R Distance 0.25394752621650696
# Nearest neighbor 4: 1574, MO-R Distance 0.25782543420791626
# Nearest neighbor 5: 1539, MO-R Distance 0.2650044560432434
# most common label was MO-R which != -B
# Nearest neighbor 1: 1557, MO-R Distance 0.2676823139190674
# Nearest neighbor 2: 1588, MO-R Distance 0.2728033661842346
# Nearest neighbor 3: 1452, MO-R Distance 0.279689222574234
# Nearest neighbor 4: 1539, MO-R Distance 0.29295676946640015
# Nearest neighbor 5: 1578, MO-R Distance 0.31530871987342834
# most common label was MO-R which != -B
# Nearest neighbor 1: 2426, L-MB Distance 0.2738679051399231
# Nearest neighbor 2: 1661, MO-R Distance 0.2739109992980957
# Nearest neighbor 3: 970, -Y Distance 0.279796302318573
# Nearest neighbor 4: 699, -Y Distance 0.28367072343826294
# Nearest neighbor 5: 542, -Y Distance 0.2905828356742859
# most common label was -Y which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2773191034793854
# Nearest neighbor 2: 1498, MO-R Distance 0.27865099906921387
# Nearest neighbor 3: 1569, MO-R Distance 0.2822468876838684
# Nearest neighbor 4: 1647, MO-R Distance 0.29228606820106506
# Nearest neighbor 5: 1586, MO-R Distance 0.29977700114250183
# most common label was MO-R which != -B
# Nearest neighbor 1: 1539, MO-R Distance 0.2579253315925598
# Nearest neighbor 2: 1661, MO-R Distance 0.2722355127334595
# Nearest neighbor 3: 1586, MO-R Distance 0.27657806873321533
# Nearest neighbor 4: 1592, MO-R Distance 0.27995988726615906
# Nearest neighbor 5: 1609, MO-R Distance 0.2804780602455139
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.2532392740249634
# Nearest neighbor 2: 1557, MO-R Distance 0.2649804651737213
# Nearest neighbor 3: 1592, MO-R Distance 0.2664424180984497
# Nearest neighbor 4: 1452, MO-R Distance 0.2667733132839203
# Nearest neighbor 5: 1498, MO-R Distance 0.2746565639972687
# most common label was MO-R which != -B
# Nearest neighbor 1: 1592, MO-R Distance 0.25321725010871887
# Nearest neighbor 2: 1661, MO-R Distance 0.2535254657268524
# Nearest neighbor 3: 1494, MO-R Distance 0.25402194261550903
# Nearest neighbor 4: 1539, MO-R Distance 0.25959715247154236
# Nearest neighbor 5: 278, -Y Distance 0.2640926241874695
# most common label was MO-R which != -B
# Nearest neighbor 1: 1661, MO-R Distance 0.26509416103363037
# Nearest neighbor 2: 1498, MO-R Distance 0.2698117792606354
# Nearest neighbor 3: 1539, MO-R Distance 0.2817375659942627
# Nearest neighbor 4: 1592, MO-R Distance 0.2848826050758362
# Nearest neighbor 5: 1569, MO-R Distance 0.28707075119018555
# most common label was MO-R which != -B
# Nearest neighbor 1: 1647, MO-R Distance 0.2404455840587616
# Nearest neighbor 2: 1546, MO-R Distance 0.26106834411621094
# Nearest neighbor 3: 1615, MO-R Distance 0.26161471009254456
# Nearest neighbor 4: 1539, MO-R Distance 0.26304465532302856
# Nearest neighbor 5: 1661, MO-R Distance 0.2727152109146118
# most common label was MO-R which != -B
# Nearest neighbor 1: 1557, MO-R Distance 0.2016548216342926
# ...
# Nearest neighbor 3: 1539, MO-R Distance 0.26877930760383606
# Nearest neighbor 4: 1513, MO-R Distance 0.2726738750934601
# Nearest neighbor 5: 1667, MO-R Distance 0.2799825370311737
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1513, MO-R Distance 0.31804490089416504
# Nearest neighbor 2: 1158, PR-K Distance 0.3294006586074829
# Nearest neighbor 3: 1462, MO-R Distance 0.33422404527664185
# Nearest neighbor 4: 1151, PR-K Distance 0.3377613425254822
# Nearest neighbor 5: 1155, PR-K Distance 0.3419637680053711
# most common label was PR-K which != L-MB
# Nearest neighbor 1: 167, K-WP Distance 0.29430073499679565
# Nearest neighbor 2: 909, -Y Distance 0.30305352807044983
# Nearest neighbor 3: 363, -Y Distance 0.3085191249847412
# Nearest neighbor 4: 1494, MO-R Distance 0.32716599106788635
# Nearest neighbor 5: 1574, MO-R Distance 0.3298259973526001
# most common label was -Y which != L-MB
# Nearest neighbor 1: 1574, MO-R Distance 0.29800769686698914
# Nearest neighbor 2: 167, K-WP Distance 0.30185794830322266
# Nearest neighbor 3: 2400, L-MB Distance 0.3118618130683899
# Nearest neighbor 4: 1557, MO-R Distance 0.3120596408843994
# Nearest neighbor 5: 168, K-WP Distance 0.31573522090911865
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1539, MO-R Distance 0.3157734274864197
# Nearest neighbor 2: 1574, MO-R Distance 0.3341556787490845
# Nearest neighbor 3: 1414, MO-R Distance 0.3352309465408325
# Nearest neighbor 4: 1597, MO-R Distance 0.3357769846916199
# Nearest neighbor 5: 1466, MO-R Distance 0.340490460395813
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 451, -Y Distance 0.2876185178756714
# Nearest neighbor 2: 323, -Y Distance 0.31371453404426575
# Nearest neighbor 3: 1574, MO-R Distance 0.3169405460357666
# Nearest neighbor 4: 967, -Y Distance 0.31860214471817017
# Nearest neighbor 5: 432, -Y Distance 0.3234682083129883
# most common label was -Y which != L-MB
# Nearest neighbor 1: 167, K-WP Distance 0.26562273502349854
# Nearest neighbor 2: 451, -Y Distance 0.2971803843975067
# Nearest neighbor 3: 2426, L-MB Distance 0.2984877824783325
# Nearest neighbor 4: 967, -Y Distance 0.308932900428772
# Nearest neighbor 5: 247, K-WP Distance 0.31276875734329224
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 1824, WX-P Distance 0.29885396361351013
# Nearest neighbor 2: 168, K-WP Distance 0.3158983290195465
# Nearest neighbor 3: 167, K-WP Distance 0.3197823762893677
# Nearest neighbor 4: 1574, MO-R Distance 0.3238111138343811
# Nearest neighbor 5: 1494, MO-R Distance 0.3360750377178192
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 2398, L-MB Distance 0.3255089819431305
# Nearest neighbor 2: 1513, MO-R Distance 0.32910704612731934
# Nearest neighbor 3: 1628, MO-R Distance 0.33395516872406006
# Nearest neighbor 4: 1466, MO-R Distance 0.33586493134498596
# Nearest neighbor 5: 1597, MO-R Distance 0.34804412722587585
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 2398, L-MB Distance 0.3200207054615021
# Nearest neighbor 2: 1414, MO-R Distance 0.3394757807254791
# Nearest neighbor 3: 2424, L-MB Distance 0.3555467128753662
# Nearest neighbor 4: 1399, MO-R Distance 0.35701754689216614
# Nearest neighbor 5: 1384, MO-R Distance 0.35953325033187866
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1539, MO-R Distance 0.26629897952079773
# Nearest neighbor 2: 1574, MO-R Distance 0.2777211666107178
# Nearest neighbor 3: 219, K-WP Distance 0.28343498706817627
# Nearest neighbor 4: 1466, MO-R Distance 0.28586345911026
# Nearest neighbor 5: 1597, MO-R Distance 0.2893425226211548
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 167, K-WP Distance 0.27013805508613586
# Nearest neighbor 2: 168, K-WP Distance 0.2843714952468872
# Nearest neighbor 3: 771, -Y Distance 0.3062748312950134
# Nearest neighbor 4: 628, -Y Distance 0.30665239691734314
# Nearest neighbor 5: 1574, MO-R Distance 0.3079759478569031
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 167, K-WP Distance 0.2783214747905731
# Nearest neighbor 2: 168, K-WP Distance 0.2870257496833801
# Nearest neighbor 3: 1824, WX-P Distance 0.2960326671600342
# Nearest neighbor 4: 1574, MO-R Distance 0.31365668773651123
# Nearest neighbor 5: 157, K-WP Distance 0.33021390438079834
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 1983, WX-P Distance 0.3976078927516937
# Nearest neighbor 2: 1824, WX-P Distance 0.4058339595794678
# Nearest neighbor 3: 2395, L-MB Distance 0.432654470205307
# Nearest neighbor 4: 2028, WX-P Distance 0.4372768998146057
# Nearest neighbor 5: 2398, L-MB Distance 0.4383319914340973
# most common label was WX-P which != L-MB
# Nearest neighbor 1: 1384, MO-R Distance 0.30103904008865356
# Nearest neighbor 2: 2398, L-MB Distance 0.3076234459877014
# Nearest neighbor 3: 1597, MO-R Distance 0.3150871992111206
# Nearest neighbor 4: 1824, WX-P Distance 0.31845661997795105
# Nearest neighbor 5: 2028, WX-P Distance 0.33780568838119507
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1513, MO-R Distance 0.23458853363990784
# Nearest neighbor 2: 1380, MO-R Distance 0.24024327099323273
# Nearest neighbor 3: 1466, MO-R Distance 0.25251978635787964
# Nearest neighbor 4: 1525, MO-R Distance 0.25952571630477905
# Nearest neighbor 5: 1628, MO-R Distance 0.2612071633338928
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 219, K-WP Distance 0.279241144657135
# Nearest neighbor 2: 1574, MO-R Distance 0.2881985902786255
# Nearest neighbor 3: 1588, MO-R Distance 0.3081780672073364
# Nearest neighbor 4: 1586, MO-R Distance 0.3152300715446472
# Nearest neighbor 5: 1557, MO-R Distance 0.315886527299881
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1588, MO-R Distance 0.2600947618484497
# Nearest neighbor 2: 1647, MO-R Distance 0.2618129849433899
# Nearest neighbor 3: 1557, MO-R Distance 0.27596068382263184
# Nearest neighbor 4: 1574, MO-R Distance 0.27663296461105347
# Nearest neighbor 5: 1539, MO-R Distance 0.2772335410118103
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 168, K-WP Distance 0.3424709737300873
# Nearest neighbor 2: 167, K-WP Distance 0.3451438546180725
# Nearest neighbor 3: 1574, MO-R Distance 0.3493422269821167
# Nearest neighbor 4: 1539, MO-R Distance 0.35160279273986816
# Nearest neighbor 5: 674, -Y Distance 0.3548041880130768
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 167, K-WP Distance 0.32378074526786804
# Nearest neighbor 2: 168, K-WP Distance 0.36396265029907227
# Nearest neighbor 3: 1574, MO-R Distance 0.36524516344070435
# Nearest neighbor 4: 219, K-WP Distance 0.373274564743042
# Nearest neighbor 5: 157, K-WP Distance 0.37364837527275085
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 1414, MO-R Distance 0.2715591788291931
# Nearest neighbor 2: 2398, L-MB Distance 0.2732844054698944
# Nearest neighbor 3: 1466, MO-R Distance 0.3105009198188782
# Nearest neighbor 4: 1513, MO-R Distance 0.3252379596233368
# Nearest neighbor 5: 1399, MO-R Distance 0.32543492317199707
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1597, MO-R Distance 0.27044761180877686
# Nearest neighbor 2: 1628, MO-R Distance 0.2734050154685974
# Nearest neighbor 3: 1525, MO-R Distance 0.28174877166748047
# Nearest neighbor 4: 1605, MO-R Distance 0.2902965843677521
# Nearest neighbor 5: 1466, MO-R Distance 0.29138684272766113
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 167, K-WP Distance 0.32650262117385864
# Nearest neighbor 2: 168, K-WP Distance 0.35663700103759766
# Nearest neighbor 3: 243, K-WP Distance 0.3811269998550415
# Nearest neighbor 4: 1824, WX-P Distance 0.38716164231300354
# Nearest neighbor 5: 745, -Y Distance 0.3944176733493805
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 2395, L-MB Distance 0.42337554693222046
# Nearest neighbor 2: 2408, L-MB Distance 0.4278181195259094
# Nearest neighbor 3: 2398, L-MB Distance 0.4341294765472412
# Nearest neighbor 4: 1983, WX-P Distance 0.4437575936317444
# Nearest neighbor 5: 1399, MO-R Distance 0.44443559646606445
# most common label was L-MB which == original label L-MB
# Nearest neighbor 1: 168, K-WP Distance 0.32161563634872437
# Nearest neighbor 2: 167, K-WP Distance 0.33492231369018555
# Nearest neighbor 3: 1983, WX-P Distance 0.34209975600242615
# Nearest neighbor 4: 1824, WX-P Distance 0.3429937958717346
# Nearest neighbor 5: 745, -Y Distance 0.3455964922904968
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 451, -Y Distance 0.2885069251060486
# Nearest neighbor 2: 1574, MO-R Distance 0.30294567346572876
# Nearest neighbor 3: 219, K-WP Distance 0.3192801773548126
# Nearest neighbor 4: 167, K-WP Distance 0.3210333287715912
# Nearest neighbor 5: 1588, MO-R Distance 0.3283834457397461
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 167, K-WP Distance 0.3361736834049225
# Nearest neighbor 2: 2426, L-MB Distance 0.3418342173099518
# Nearest neighbor 3: 451, -Y Distance 0.34584516286849976
# Nearest neighbor 4: 168, K-WP Distance 0.3485807776451111
# Nearest neighbor 5: 219, K-WP Distance 0.34960049390792847
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 1574, MO-R Distance 0.2508050799369812
# Nearest neighbor 2: 1575, MO-R Distance 0.26416268944740295
# Nearest neighbor 3: 1592, MO-R Distance 0.26946964859962463
# Nearest neighbor 4: 971, -Y Distance 0.2751714289188385
# Nearest neighbor 5: 451, -Y Distance 0.27554967999458313
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1824, WX-P Distance 0.3927660882472992
# Nearest neighbor 2: 1983, WX-P Distance 0.42362284660339355
# Nearest neighbor 3: 2424, L-MB Distance 0.433508038520813
# Nearest neighbor 4: 1404, MO-R Distance 0.43607282638549805
# Nearest neighbor 5: 1416, MO-R Distance 0.4369942843914032
# most common label was WX-P which != L-MB
# Nearest neighbor 1: 1574, MO-R Distance 0.32686352729797363
# Nearest neighbor 2: 168, K-WP Distance 0.33239907026290894
# Nearest neighbor 3: 167, K-WP Distance 0.34264159202575684
# Nearest neighbor 4: 157, K-WP Distance 0.36592185497283936
# Nearest neighbor 5: 1592, MO-R Distance 0.36928993463516235
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 1377, MO-R Distance 0.29415538907051086
# Nearest neighbor 2: 1578, MO-R Distance 0.29654932022094727
# Nearest neighbor 3: 1414, MO-R Distance 0.3115620017051697
# Nearest neighbor 4: 1597, MO-R Distance 0.31940972805023193
# Nearest neighbor 5: 1656, MO-R Distance 0.31977933645248413
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 167, K-WP Distance 0.2883971035480499
# Nearest neighbor 2: 168, K-WP Distance 0.294405996799469
# Nearest neighbor 3: 1574, MO-R Distance 0.30082273483276367
# Nearest neighbor 4: 1539, MO-R Distance 0.3067930340766907
# Nearest neighbor 5: 2426, L-MB Distance 0.31695306301116943
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 159, K-WP Distance 0.360825777053833
# Nearest neighbor 2: 2400, L-MB Distance 0.36108607053756714
# Nearest neighbor 3: 1414, MO-R Distance 0.3662993609905243
# Nearest neighbor 4: 168, K-WP Distance 0.37062135338783264
# Nearest neighbor 5: 2398, L-MB Distance 0.3779429793357849
# most common label was K-WP which != L-MB
# Nearest neighbor 1: 1597, MO-R Distance 0.35256144404411316
# Nearest neighbor 2: 1824, WX-P Distance 0.360348641872406
# Nearest neighbor 3: 1574, MO-R Distance 0.3644621968269348
# Nearest neighbor 4: 168, K-WP Distance 0.3698907494544983
# Nearest neighbor 5: 1384, MO-R Distance 0.3747459948062897
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1525, MO-R Distance 0.23204366862773895
# Nearest neighbor 2: 1466, MO-R Distance 0.23658254742622375
# Nearest neighbor 3: 1578, MO-R Distance 0.24402348697185516
# Nearest neighbor 4: 1377, MO-R Distance 0.24561701714992523
# Nearest neighbor 5: 1431, MO-R Distance 0.2507508099079132
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 2426, L-MB Distance 0.28006863594055176
# Nearest neighbor 2: 967, -Y Distance 0.30733442306518555
# Nearest neighbor 3: 451, -Y Distance 0.31529635190963745
# Nearest neighbor 4: 2420, L-MB Distance 0.3158947229385376
# Nearest neighbor 5: 167, K-WP Distance 0.3189460337162018
# most common label was L-MB which == original label L-MB
# Nearest neighbor 1: 1466, MO-R Distance 0.26665663719177246
# Nearest neighbor 2: 1597, MO-R Distance 0.2718319296836853
# Nearest neighbor 3: 1387, MO-R Distance 0.28252238035202026
# Nearest neighbor 4: 1525, MO-R Distance 0.28548383712768555
# Nearest neighbor 5: 1414, MO-R Distance 0.2859276831150055
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1574, MO-R Distance 0.2637982964515686
# Nearest neighbor 2: 1466, MO-R Distance 0.28671711683273315
# Nearest neighbor 3: 1539, MO-R Distance 0.2903437316417694
# Nearest neighbor 4: 1592, MO-R Distance 0.2925689220428467
# Nearest neighbor 5: 1597, MO-R Distance 0.2992570400238037
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1597, MO-R Distance 0.24864697456359863
# Nearest neighbor 2: 1574, MO-R Distance 0.25601106882095337
# Nearest neighbor 3: 1494, MO-R Distance 0.2772311568260193
# Nearest neighbor 4: 1539, MO-R Distance 0.2779904901981354
# Nearest neighbor 5: 1592, MO-R Distance 0.292768657207489
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1574, MO-R Distance 0.24174195528030396
# Nearest neighbor 2: 1588, MO-R Distance 0.24958297610282898
# Nearest neighbor 3: 1586, MO-R Distance 0.25232887268066406
# Nearest neighbor 4: 1557, MO-R Distance 0.25253063440322876
# Nearest neighbor 5: 1592, MO-R Distance 0.25447022914886475
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 2400, L-MB Distance 0.28150618076324463
# Nearest neighbor 2: 1597, MO-R Distance 0.28888562321662903
# Nearest neighbor 3: 1574, MO-R Distance 0.29156944155693054
# Nearest neighbor 4: 1384, MO-R Distance 0.2943000793457031
# Nearest neighbor 5: 1525, MO-R Distance 0.2951069474220276
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1597, MO-R Distance 0.2944514751434326
# Nearest neighbor 2: 1539, MO-R Distance 0.30181682109832764
# Nearest neighbor 3: 1628, MO-R Distance 0.30594831705093384
# Nearest neighbor 4: 1574, MO-R Distance 0.31020092964172363
# Nearest neighbor 5: 211, K-WP Distance 0.31447863578796387
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 451, -Y Distance 0.25581294298171997
# Nearest neighbor 2: 1574, MO-R Distance 0.2802201509475708
# Nearest neighbor 3: 561, -Y Distance 0.2928798198699951
# Nearest neighbor 4: 167, K-WP Distance 0.29399943351745605
# Nearest neighbor 5: 1592, MO-R Distance 0.2945363521575928
# most common label was -Y which != L-MB
# Nearest neighbor 1: 2424, L-MB Distance 0.3462969660758972
# Nearest neighbor 2: 2398, L-MB Distance 0.34771209955215454
# Nearest neighbor 3: 159, K-WP Distance 0.36413514614105225
# Nearest neighbor 4: 1384, MO-R Distance 0.3712693452835083
# Nearest neighbor 5: 202, K-WP Distance 0.3783576488494873
# most common label was L-MB which == original label L-MB
# Nearest neighbor 1: 1574, MO-R Distance 0.310897558927536
# Nearest neighbor 2: 219, K-WP Distance 0.3153229355812073
# Nearest neighbor 3: 451, -Y Distance 0.3214171528816223
# Nearest neighbor 4: 1586, MO-R Distance 0.32730966806411743
# Nearest neighbor 5: 2420, L-MB Distance 0.3279392719268799
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1414, MO-R Distance 0.2546900808811188
# Nearest neighbor 2: 1466, MO-R Distance 0.28148171305656433
# Nearest neighbor 3: 1597, MO-R Distance 0.2877126932144165
# Nearest neighbor 4: 1617, MO-R Distance 0.29395464062690735
# Nearest neighbor 5: 1539, MO-R Distance 0.297027587890625
# most common label was MO-R which != L-MB
# Nearest neighbor 1: 1597, MO-R Distance 0.23471751809120178
# Nearest neighbor 2: 1377, MO-R Distance 0.24351125955581665
# Nearest neighbor 3: 1414, MO-R Distance 0.24475795030593872
# Nearest neighbor 4: 1466, MO-R Distance 0.2626093626022339
# Nearest neighbor 5: 1673, MO-R Distance 0.26545846462249756
# most common label was MO-R which != L-MB
# Total accuracy: 0.22039095438865466
# Median of all distances: 0.3014538288116455
# Median distance of incorrect guesses: 0.30454230308532715
# Median distance of correct guesses: 0.27775347232818604
# Lowest: 0.16008950769901276 highest: 0.6987410187721252
